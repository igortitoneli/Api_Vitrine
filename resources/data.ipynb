# %% [markdown]
# # Importando bibliotecas

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from lazypredict.Supervised import LazyRegressor
from sklearn.metrics import mean_absolute_percentage_error
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Funções

# %%
# Funções   

def train(property_dfs,tipo):

    # particionando dados 

    df = property_dfs[tipo]

    X = df.drop(columns='Preço')
    y = df['Preço']

    # testa Lazy predict armazenando um vetor de todos os valores, a media, e o desvio padrao

    dict_result = {}

    for i in range(33):
            
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

        reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric= mean_absolute_percentage_error)
        models, _ = reg.fit(X_train, X_test, y_train, y_test)

        for model_name, methods in models.iterrows():

            if model_name not in dict_result:
                dict_result[model_name] = {}
                
            for met, val in methods.items():
                if met not in dict_result[model_name]:
                    dict_result[model_name][met] = {
                        "mean": [],
                        "media": 0,
                        "std": 0
                    }

                dict_result[model_name][met]["mean"].append(val)
    
    return dict_result

# %% [markdown]
# # Normalização

# %%
def norm_min_max(df):

    columns_to_normalize = [col for col in df.columns if col != "Tipo" and df[col].dtype != object]

    for col in columns_to_normalize :
        min_values = df[columns_to_normalize].min()
        max_values = df[columns_to_normalize].max()        
    # min_values = df[columns_to_normalize].min()
    # max_values = df[columns_to_normalize].max()
        df[columns_to_normalize] = (df[columns_to_normalize] - min_values) / (max_values - min_values)
    
    return df

# %% [markdown]
# # Formatação dos dados

# %%
#Le e trata a database

tabela = '/home/igor/Documentos/stemis/Api_Vitrine/webscraping/Web Scraping_Setor1_Completo_Lat_Long.xlsx'
df = pd.read_excel(tabela)

df.drop(df.columns[df.columns.str.contains('unnamed', case=False)], axis=1, inplace=True)
df = df.drop(['ID', 'Cidade', 'Bairro'], axis=1)
df['Tipo'] = df['Tipo'].replace({'Ã£': 'ã', 'Ã©': 'é', 'Ã_x0081_': 'Á'}, regex=True)
df = df.drop(df[df['Tipo'].isin(['Salão', 'Terreno', 'Prédio', 'Sobrado', 'Flat', 'Ponto', 'Área', 'Laje'])].index)
df['Tipo'] = df['Tipo'].replace({'Kitnet': 'Studio'}, regex=True)

money_col = df[['Preço', 'Condomínio', 'IPTU']]
for col in money_col:
    df[col] = df[col].astype(str).apply(lambda x: x.replace('.', ''))
    df[col] = df[col].replace({'R\$ ': '', ',': '.'}, regex=True).astype('float64')
int_col = df[['Quartos', 'Banheiros', 'Vagas']]
for col in int_col:
    df[col] = df[col].astype(int)
df = df.reset_index(drop=True)

df = df.drop_duplicates()

property_types = df['Tipo'].unique()

property_dfs = {}

for property_type in property_types:
    property_dfs[property_type] = norm_min_max(df[df['Tipo'] == property_type])

print(property_dfs)
# Out:
# {'Studio':        Tipo   m2  Quartos  Banheiros  Vagas  Preço  Condomínio  IPTU  \
# 0    Studio 0.06     0.20       0.25   0.00   0.10        0.10  0.00
# 47   Studio 0.12     0.40       0.25   0.33   0.07        0.20  0.26
# 50   Studio 0.14     0.40       0.25   0.33   0.09        0.21  0.34
# 72   Studio 0.14     0.80       0.50   0.00   0.18        0.00  0.37
# 85   Studio 0.05     0.20       0.25   0.00   0.00        0.00  0.05
# 129  Studio 0.26     1.00       0.75   1.00   0.36        0.00  0.60
# 130  Studio 0.12     0.40       0.25   0.33   0.04        0.10  0.32
# 168  Studio 0.66     1.00       1.00   1.00   0.48        0.08  0.70
# 175  Studio 0.41     0.80       1.00   0.67   0.27        0.52  0.82
# 178  Studio 0.07     0.40       0.25   0.00   0.06        0.12  0.19
# 180  Studio 0.14     0.40       0.50   0.33   0.12        0.36  0.37
# 190  Studio 0.08     0.20       0.25   0.00   0.04        0.23  0.27
# 262  Studio 0.10     0.20       0.25   0.00   0.02        0.00  0.00
# 265  Studio 0.08     0.00       0.25   0.00   0.21        0.75  0.20
# 266  Studio 0.41     0.80       1.00   0.67   0.29        0.23  0.55
# 267  Studio 0.20     0.40       0.25   0.00   0.04        0.07  0.00
# 274  Studio 0.05     0.20       0.25   0.00   0.07        0.14  0.27
# 286  Studio 0.12     0.40       0.25   0.00   0.05        0.10  0.17
# 292  Studio 0.28     0.00       0.75   1.00   0.68        1.00  1.00
# 293  Studio 0.05     0.00       0.25   0.00   0.10        0.14  0.27
# 311  Studio 0.39     0.80       1.00   0.67   0.32        0.51  0.85
# 355  Studio 0.00     0.60       0.00   0.00   0.06        0.00  0.15
# 384  Studio 0.05     0.00       0.25   0.67   0.06        0.37  0.45
# 402  Studio 1.00     0.00       0.00   0.00   1.00        0.00  0.00
# 412  Studio 0.07     0.20       0.25   0.00   0.05        0.19  0.33
# 460  Studio 0.08     0.40       0.25   0.33   0.05        0.11  0.00
# 484  Studio 0.12     0.20       0.25   0.33   0.09        0.15  0.34
# 503  Studio 0.06     0.00       0.25   0.00   0.06        0.27  0.23
# 504  Studio 0.11     0.40       0.25   0.33   0.05        0.11  0.25
# 506  Studio 0.13     0.40       0.25   0.33   0.03        0.12  0.00
# 507  Studio 0.10     0.40       0.25   0.00   0.05        0.08  0.00
# 508  Studio 0.10     0.40       0.25   0.00   0.05        0.10  0.12
# 509  Studio 0.28     0.60       0.75   0.33   0.07        0.00  0.48
# 511  Studio 0.11     0.40       0.25   0.33   0.04        0.14  0.18
# 512  Studio 0.67     0.00       0.75   0.67   1.00        0.00  0.45
# 534  Studio 0.08     0.00       0.25   0.00   0.15        0.16  0.21
# 536  Studio 0.15     0.60       0.25   0.00   0.06        0.09  0.39
# 538  Studio 0.25     0.00       0.50   0.00   0.43        0.22  0.52
# 543  Studio 0.06     0.00       0.25   0.00   0.06        0.00  0.30
# 574  Studio 0.11     0.40       0.25   0.33   0.03        0.13  0.10
# 575  Studio 0.11     0.40       0.50   0.33   0.07        0.08  0.23
# 583  Studio 0.08     0.00       0.25   0.00   0.05        0.24  0.25
# 637  Studio 0.16     0.60       0.50   0.00   0.07        0.17  0.34
# 708  Studio 0.11     0.40       0.25   0.00   0.03        0.16  0.31
# 716  Studio 0.13     0.00       0.00   0.00   0.22        0.00  0.11
# 758  Studio 0.10     0.00       0.25   0.33   0.03        0.30  0.44
# 828  Studio 0.17     0.00       0.00   0.00   0.48        0.00  0.00
# 877  Studio 0.06     0.20       0.25   0.00   0.03        0.14  0.15
# 884  Studio 0.05     0.20       0.25   0.00   0.08        0.00  0.00
#
#      Latitude  Longitude
# 0        0.27       0.96
# 47       0.27       0.96
# 50       0.27       0.96
# 72       0.27       0.96
# 85       0.15       0.52
# 129      0.15       0.52
# 130      0.27       0.96
# 168      0.12       0.88
# 175      0.27       0.96
# 178      0.27       0.96
# 180      0.27       0.96
# 190      0.15       0.52
# 262      0.27       0.96
# 265      0.27       0.96
# 266      0.27       0.96
# 267      0.27       0.96
# 274      0.15       0.52
# 286      0.27       0.96
# 292      0.27       0.96
# 293      0.27       0.96
# 311      0.00       0.88
# 355      0.27       0.96
# 384      0.27       0.96
# 402      0.27       0.96
# 412      0.27       0.96
# 460      0.27       0.96
# 484      0.27       0.96
# 503      0.27       0.96
# 504      0.27       0.96
# 506      0.27       0.96
# 507      0.27       0.96
# 508      0.27       0.96
# 509      0.27       0.96
# 511      0.27       0.96
# 512      0.27       0.96
# 534      0.27       0.96
# 536      0.27       0.96
# 538      0.27       0.96
# 543      0.27       0.96
# 574      0.12       0.88
# 575      0.09       1.00
# 583      0.27       0.96
# 637      0.27       0.96
# 708      0.00       0.88
# 716      0.12       0.88
# 758      0.27       0.96
# 828      0.27       0.96
# 877      1.00       0.00
# 884      0.09       1.00  , 'Apartamento':             Tipo   m2  Quartos  Banheiros  Vagas  Preço  Condomínio  IPTU  \
# 1    Apartamento 0.01     0.30       0.17   0.00   0.03        0.09  0.02
# 2    Apartamento 0.00     0.20       0.08   0.00   0.01        0.05  0.02
# 3    Apartamento 0.01     0.10       0.08   0.04   0.02        0.17  0.02
# 4    Apartamento 0.01     0.20       0.08   0.04   0.01        0.12  0.00
# 5    Apartamento 0.01     0.20       0.08   0.04   0.01        0.07  0.01
# ..           ...  ...      ...        ...    ...    ...         ...   ...
# 899  Apartamento 0.10     0.00       0.00   1.00   0.42        0.00  0.00
# 900  Apartamento 0.09     0.00       0.83   0.43   0.50        0.00  0.00
# 901  Apartamento 0.03     0.00       0.08   0.00   0.16        0.00  0.08
# 903  Apartamento 0.01     0.20       0.08   0.00   0.01        0.04  0.00
# 913  Apartamento 0.01     0.10       0.08   0.00   0.01        0.01  0.00
#
#      Latitude  Longitude
# 1        0.07       0.20
# 2        0.06       0.27
# 3        0.09       0.20
# 4        0.17       0.09
# 5        0.02       0.11
# ..        ...        ...
# 899      0.08       0.24
# 900      0.07       0.18
# 901      0.05       0.20
# 903      0.06       0.18
# 913      0.12       0.11
#
# [501 rows x 10 columns], 'Galpão':        Tipo   m2  Quartos  Banheiros  Vagas  Preço  Condomínio  IPTU  \
# 7    Galpão 1.00     0.00       1.00   0.00   1.00        0.00  0.98
# 43   Galpão 0.00     0.50       0.00   0.50   0.00        0.29  0.00
# 139  Galpão 0.03     0.00       0.00   0.00   0.02        0.17  0.05
# 170  Galpão 0.02     0.50       0.17   1.00   0.01        0.58  0.07
# 212  Galpão 0.01     0.00       0.08   0.00   0.01        0.00  0.00
# 222  Galpão 0.02     0.00       0.08   0.00   0.02        0.11  0.06
# 223  Galpão 0.02     0.50       0.08   0.00   0.01        0.17  0.04
# 228  Galpão 0.05     0.00       0.00   0.00   0.03        0.00  0.21
# 246  Galpão 0.01     0.50       0.08   0.00   0.00        0.20  0.01
# 301  Galpão 0.01     0.50       0.17   0.00   0.01        0.25  0.04
# 342  Galpão 0.07     0.00       0.08   0.00   0.05        0.00  0.18
# 393  Galpão 0.01     0.25       0.08   0.00   0.00        0.39  0.02
# 428  Galpão 0.02     1.00       0.17   0.00   0.02        0.00  0.05
# 429  Galpão 0.02     0.00       0.17   0.00   0.07        0.00  0.20
# 498  Galpão 0.01     0.25       0.08   0.00   0.01        0.39  0.04
# 610  Galpão 0.01     0.00       0.08   0.00   0.01        0.00  0.05
# 611  Galpão 0.03     0.00       0.17   0.00   0.15        0.34  0.23
# 663  Galpão 0.01     0.00       0.08   0.00   0.01        0.18  0.03
# 703  Galpão 0.01     0.50       0.08   0.50   0.01        0.29  0.00
# 718  Galpão 0.02     0.00       0.08   0.00   0.03        0.00  0.00
# 772  Galpão 0.01     0.00       0.08   0.50   0.02        0.73  0.07
# 778  Galpão 0.02     0.00       0.17   0.00   0.26        1.00  1.00
# 799  Galpão 0.02     0.00       0.00   0.00   0.59        0.00  0.00
# 807  Galpão 0.02     0.50       0.08   0.50   0.01        0.34  0.03
# 842  Galpão 0.01     0.50       0.08   0.00   0.01        0.20  0.02
# 843  Galpão 0.00     0.00       0.00   0.50   0.00        0.10  0.00
# 848  Galpão 0.00     0.00       0.17   0.00   0.02        0.00  0.00
# 888  Galpão 0.01     0.50       0.08   0.50   0.01        0.34  0.02
# 914  Galpão 0.01     0.25       0.08   0.00   0.00        0.30  0.02
#
#      Latitude  Longitude
# 7        0.78       0.13
# 43       0.57       0.32
# 139      0.52       0.28
# 170      0.78       0.13
# 212      0.37       0.73
# 222      0.34       0.79
# 223      0.34       0.85
# 228      0.48       0.72
# 246      0.52       0.62
# 301      0.54       0.43
# 342      0.70       0.23
# 393      0.54       0.43
# 428      0.34       0.79
# 429      0.52       0.62
# 498      0.16       0.44
# 610      0.50       0.67
# 611      0.50       0.67
# 663      0.37       0.73
# 703      0.60       0.73
# 718      1.00       0.00
# 772      0.52       0.62
# 778      0.21       0.86
# 799      0.50       0.53
# 807      1.00       0.00
# 842      0.00       0.51
# 843      0.34       0.79
# 848      0.78       0.13
# 888      0.59       0.31
# 914      0.26       1.00  , 'Casa':      Tipo   m2  Quartos  Banheiros  Vagas  Preço  Condomínio  IPTU  Latitude  \
# 9    Casa 0.07     0.60       0.50   0.00   0.05        0.00  0.00      0.37
# 32   Casa 0.02     0.20       0.25   0.00   0.05        0.15  0.00      0.44
# 36   Casa 0.06     0.20       0.25   0.17   0.02        0.79  0.07      0.34
# 38   Casa 0.25     0.80       1.00   1.00   0.39        0.24  0.03      0.35
# 46   Casa 0.07     0.60       0.50   0.00   0.08        0.30  0.04      0.62
# ..    ...  ...      ...        ...    ...    ...         ...   ...       ...
# 826  Casa 0.03     0.20       0.25   0.00   0.02        0.24  0.03      0.29
# 833  Casa 0.02     0.00       0.25   0.00   0.02        0.44  0.09      0.27
# 865  Casa 0.02     0.00       0.25   0.00   0.01        0.22  0.03      0.84
# 902  Casa 0.05     0.40       0.25   0.17   0.02        0.27  0.03      0.56
# 906  Casa 0.02     0.00       0.00   0.00   0.01        0.16  0.03      0.36
#
#      Longitude
# 9         0.81
# 32        0.68
# 36        0.69
# 38        0.67
# 46        0.76
# ..         ...
# 826       0.84
# 833       0.76
# 865       0.51
# 902       0.73
# 906       0.79
#
# [72 rows x 10 columns], 'Sala':      Tipo   m2  Quartos  Banheiros  Vagas  Preço  Condomínio  IPTU  Latitude  \
# 10   Sala 0.06     0.00       0.33   0.00   0.06        0.00  0.09      0.61
# 24   Sala 0.05     0.00       0.00   0.00   0.08        0.00  0.00      0.61
# 79   Sala 0.03     0.67       0.17   0.03   0.04        0.00  0.02      0.04
# 81   Sala 0.02     0.00       0.00   0.00   0.11        0.05  0.03      0.04
# 91   Sala 0.02     0.33       0.17   0.00   0.02        0.00  0.00      0.04
# ..    ...  ...      ...        ...    ...    ...         ...   ...       ...
# 891  Sala 0.05     0.67       0.17   0.00   0.01        0.03  0.00      0.61
# 893  Sala 0.00     0.00       0.00   0.03   0.00        0.02  0.00      0.61
# 895  Sala 0.03     0.00       0.00   0.00   0.02        0.10  0.03      0.61
# 905  Sala 0.04     0.67       0.17   0.00   0.01        0.03  0.01      0.61
# 915  Sala 0.04     0.67       0.17   0.00   0.03        0.04  0.00      0.61
#
#      Longitude
# 10        0.85
# 24        0.85
# 79        0.51
# 81        0.51
# 91        0.51
# ..         ...
# 891       0.85
# 893       0.85
# 895       0.85
# 905       0.85
# 915       0.85
#
# [74 rows x 10 columns], 'Cobertura':           Tipo   m2  Quartos  Banheiros  Vagas  Preço  Condomínio  IPTU  \
# 13   Cobertura 0.71     1.00       0.50   0.17   0.11        0.50  0.24
# 71   Cobertura 0.00     0.00       0.00   0.00   0.14        0.00  0.20
# 77   Cobertura 1.00     1.00       0.50   0.17   0.09        0.52  0.31
# 95   Cobertura 0.05     0.33       0.50   0.00   0.05        0.70  0.13
# 153  Cobertura 0.16     0.33       0.50   0.00   0.04        0.55  0.23
# 169  Cobertura 0.79     1.00       0.50   1.00   0.41        0.00  1.00
# 200  Cobertura 0.49     0.67       0.50   0.17   0.19        0.52  0.21
# 256  Cobertura 0.29     0.67       0.50   0.17   0.00        0.45  0.22
# 259  Cobertura 0.48     0.00       1.00   0.00   1.00        0.45  0.83
# 300  Cobertura 0.10     0.33       0.50   0.00   0.16        0.34  0.00
# 316  Cobertura 0.75     0.67       0.50   0.17   0.08        1.00  0.41
# 409  Cobertura 0.46     0.67       0.50   0.17   0.08        0.29  0.34
#
#      Latitude  Longitude
# 13       0.04       1.00
# 71       0.11       0.93
# 77       0.07       0.99
# 95       0.03       0.95
# 153      0.02       0.99
# 169      0.05       1.00
# 200      1.00       0.00
# 256      0.00       1.00
# 259      0.03       0.99
# 300      0.05       0.99
# 316      0.03       0.99
# 409      0.12       0.91  , 'Loja':      Tipo   m2  Quartos  Banheiros  Vagas  Preço  Condomínio  IPTU  Latitude  \
# 20   Loja 0.05     0.40       0.08   0.00   0.04        0.02  0.00      0.39
# 21   Loja 0.09     0.40       0.25   0.33   0.11        0.16  0.07      0.39
# 22   Loja 0.06     0.00       0.08   0.00   0.03        0.00  0.04      0.05
# 51   Loja 0.06     0.40       0.08   0.00   0.02        0.06  0.04      0.32
# 52   Loja 0.03     0.20       0.08   0.00   0.07        0.06  0.06      0.32
# ..    ...  ...      ...        ...    ...    ...         ...   ...       ...
# 908  Loja 0.03     0.00       0.08   0.00   0.02        0.02  0.03      0.32
# 909  Loja 0.04     0.40       0.08   0.00   0.01        0.07  0.00      0.32
# 910  Loja 0.04     0.20       0.08   0.17   0.02        0.00  0.00      0.32
# 911  Loja 0.08     0.40       0.08   0.17   0.03        0.08  0.01      0.53
# 912  Loja 0.08     0.40       0.17   0.17   0.05        0.02  0.00      0.05
#
#      Longitude
# 20        1.00
# 21        1.00
# 22        0.93
# 51        0.91
# 52        0.91
# ..         ...
# 908       0.91
# 909       0.91
# 910       0.91
# 911       0.93
# 912       0.46
#
# [173 rows x 10 columns]}

# %% [markdown]
# # Apartamento

# %%
results_dict = train(property_dfs,"Apartamento")

results_dict_format = {}

#imprime
# for model in results_dict:
#     results_dict_format[model]={}
#     for metric in results_dict[model]:
#         mean = np.mean(results_dict[model][metric]["mean"])
#         std = np.std(results_dict[model][metric]["mean"])
#         results_dict_format[model][metric + "_media"] = mean
#         results_dict_format[model][metric + "_std"] = std

# df = pd.DataFrame(results_dict_format)
# df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])

for model in results_dict:
    results_dict_format[model] = {}
    for metric in results_dict[model]:
        
        mean = np.mean(results_dict[model][metric]["mean"])   
        std = np.std(results_dict[model][metric]["mean"])
        std_str = "{:.2f}".format(std)  # Desvio padrão com 2 casas decimais
        mean_str = "{:.2f}".format(mean)  # Média com 2 casas decimais
        mean_std_str = mean_str + " +/- " + std_str  # Média +/- Desvio padrão
            
        results_dict_format[model][metric + "_media"] = mean_std_str
        
            

df = pd.DataFrame(results_dict_format)
df_transposed = df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
df_transposed.rename(columns={"mean_absolute_percentage_error_media": "MAPE_media"}, inplace=True)
df_transposed
# Out:
# 100%|██████████| 42/42 [00:05<00:00,  7.95it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.33it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.48it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.82it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.96it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.59it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.60it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.72it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.45it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.91it/s]
# 100%|██████████| 42/42 [00:05<00:00,  8.05it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.66it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.51it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.95it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.70it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.84it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.61it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.68it/s]
# 100%|██████████| 42/42 [00:05<00:00,  8.05it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.82it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.99it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.71it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.83it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.64it/s]
# 100%|██████████| 42/42 [00:05<00:00,  8.32it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.89it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.93it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.67it/s]
# 100%|██████████| 42/42 [00:05<00:00,  8.05it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.78it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.73it/s]
# 100%|██████████| 42/42 [00:05<00:00,  7.46it/s]
# 100%|██████████| 42/42 [00:05<00:00,  8.03it/s]
#                                          Adjusted R-Squared_media  \
# SVR                                                -0.51 +/- 0.69
# QuantileRegressor                                  -0.18 +/- 0.03
# GaussianProcessRegressor                      -580.14 +/- 1576.10
# LassoLarsIC                                         0.16 +/- 0.76
# SGDRegressor                                        0.26 +/- 0.58
# OrthogonalMatchingPursuitCV                        -0.01 +/- 0.95
# KernelRidge                                         0.15 +/- 0.77
# LinearRegression                                    0.14 +/- 0.78
# TransformedTargetRegressor                          0.14 +/- 0.78
# Lars                                                0.14 +/- 0.78
# Ridge                                               0.15 +/- 0.77
# BayesianRidge                                       0.16 +/- 0.74
# RidgeCV                                             0.20 +/- 0.67
# LarsCV                                              0.12 +/- 0.67
# LassoLarsCV                                         0.12 +/- 0.67
# LassoCV                                             0.13 +/- 0.67
# ElasticNetCV                                        0.13 +/- 0.68
# NuSVR                                               0.43 +/- 0.17
# OrthogonalMatchingPursuit                          -0.16 +/- 1.04
# GradientBoostingRegressor                           0.62 +/- 0.17
# TweedieRegressor                                    0.52 +/- 0.17
# AdaBoostRegressor                                   0.63 +/- 0.11
# XGBRegressor                                        0.61 +/- 0.16
# PoissonRegressor                                    0.11 +/- 0.22
# RandomForestRegressor                               0.66 +/- 0.12
# ElasticNet                                         -0.09 +/- 0.05
# LassoLars                                          -0.09 +/- 0.05
# Lasso                                              -0.09 +/- 0.05
# DummyRegressor                                     -0.09 +/- 0.05
# BaggingRegressor                                    0.66 +/- 0.12
# ExtraTreeRegressor                                  0.30 +/- 0.34
# ExtraTreesRegressor                                 0.68 +/- 0.10
# DecisionTreeRegressor                               0.38 +/- 0.31
# RANSACRegressor                                     0.36 +/- 0.27
# LinearSVR                                           0.42 +/- 0.24
# KNeighborsRegressor                                 0.51 +/- 0.14
# LGBMRegressor                                       0.40 +/- 0.26
# HuberRegressor                                      0.40 +/- 0.28
# HistGradientBoostingRegressor                       0.40 +/- 0.29
# PassiveAggressiveRegressor                         -0.46 +/- 1.01
# GammaRegressor                 -33298392824.98 +/- 99895177964.67
# MLPRegressor                                       -2.45 +/- 3.95
#
#                                                   R-Squared_media  \
# SVR                                                -0.42 +/- 0.65
# QuantileRegressor                                  -0.10 +/- 0.03
# GaussianProcessRegressor                      -545.27 +/- 1481.54
# LassoLarsIC                                         0.21 +/- 0.71
# SGDRegressor                                        0.31 +/- 0.54
# OrthogonalMatchingPursuitCV                         0.05 +/- 0.89
# KernelRidge                                         0.20 +/- 0.72
# LinearRegression                                    0.19 +/- 0.73
# TransformedTargetRegressor                          0.19 +/- 0.73
# Lars                                                0.19 +/- 0.73
# Ridge                                               0.20 +/- 0.72
# BayesianRidge                                       0.21 +/- 0.70
# RidgeCV                                             0.25 +/- 0.63
# LarsCV                                              0.18 +/- 0.63
# LassoLarsCV                                         0.18 +/- 0.63
# LassoCV                                             0.18 +/- 0.63
# ElasticNetCV                                        0.18 +/- 0.64
# NuSVR                                               0.46 +/- 0.16
# OrthogonalMatchingPursuit                          -0.09 +/- 0.98
# GradientBoostingRegressor                           0.64 +/- 0.16
# TweedieRegressor                                    0.55 +/- 0.16
# AdaBoostRegressor                                   0.65 +/- 0.10
# XGBRegressor                                        0.63 +/- 0.15
# PoissonRegressor                                    0.16 +/- 0.21
# RandomForestRegressor                               0.68 +/- 0.11
# ElasticNet                                         -0.02 +/- 0.05
# LassoLars                                          -0.02 +/- 0.05
# Lasso                                              -0.02 +/- 0.05
# DummyRegressor                                     -0.02 +/- 0.05
# BaggingRegressor                                    0.68 +/- 0.12
# ExtraTreeRegressor                                  0.34 +/- 0.32
# ExtraTreesRegressor                                 0.70 +/- 0.10
# DecisionTreeRegressor                               0.41 +/- 0.30
# RANSACRegressor                                     0.40 +/- 0.26
# LinearSVR                                           0.45 +/- 0.22
# KNeighborsRegressor                                 0.54 +/- 0.13
# LGBMRegressor                                       0.44 +/- 0.24
# HuberRegressor                                      0.44 +/- 0.26
# HistGradientBoostingRegressor                       0.43 +/- 0.27
# PassiveAggressiveRegressor                         -0.37 +/- 0.95
# GammaRegressor                 -31300489255.42 +/- 93901467286.79
# MLPRegressor                                       -2.24 +/- 3.71
#
#                                          RMSE_media Time Taken_media  \
# SVR                                   0.08 +/- 0.01    0.01 +/- 0.00
# QuantileRegressor                     0.08 +/- 0.02    2.53 +/- 0.16
# GaussianProcessRegressor              0.95 +/- 1.35    0.01 +/- 0.00
# LassoLarsIC                           0.07 +/- 0.05    0.02 +/- 0.01
# SGDRegressor                          0.06 +/- 0.04    0.01 +/- 0.00
# OrthogonalMatchingPursuitCV           0.07 +/- 0.05    0.01 +/- 0.01
# KernelRidge                           0.07 +/- 0.05    0.01 +/- 0.00
# LinearRegression                      0.07 +/- 0.05    0.01 +/- 0.01
# TransformedTargetRegressor            0.07 +/- 0.05    0.01 +/- 0.00
# Lars                                  0.07 +/- 0.05    0.01 +/- 0.01
# Ridge                                 0.07 +/- 0.05    0.01 +/- 0.00
# BayesianRidge                         0.07 +/- 0.05    0.01 +/- 0.00
# RidgeCV                               0.07 +/- 0.04    0.01 +/- 0.00
# LarsCV                                0.07 +/- 0.04    0.02 +/- 0.01
# LassoLarsCV                           0.07 +/- 0.04    0.02 +/- 0.01
# LassoCV                               0.07 +/- 0.04    0.05 +/- 0.02
# ElasticNetCV                          0.07 +/- 0.04    0.04 +/- 0.02
# NuSVR                                 0.05 +/- 0.02    0.04 +/- 0.01
# OrthogonalMatchingPursuit             0.08 +/- 0.06    0.01 +/- 0.00
# GradientBoostingRegressor             0.04 +/- 0.01    0.06 +/- 0.01
# TweedieRegressor                      0.05 +/- 0.01    0.01 +/- 0.00
# AdaBoostRegressor                     0.04 +/- 0.01    0.06 +/- 0.02
# XGBRegressor                          0.04 +/- 0.01    0.14 +/- 0.04
# PoissonRegressor                      0.07 +/- 0.01    0.02 +/- 0.01
# RandomForestRegressor                 0.04 +/- 0.01    0.13 +/- 0.01
# ElasticNet                            0.08 +/- 0.02    0.01 +/- 0.00
# LassoLars                             0.08 +/- 0.02    0.01 +/- 0.01
# Lasso                                 0.08 +/- 0.02    0.01 +/- 0.01
# DummyRegressor                        0.08 +/- 0.02    0.01 +/- 0.00
# BaggingRegressor                      0.04 +/- 0.01    0.02 +/- 0.00
# ExtraTreeRegressor                    0.06 +/- 0.01    0.01 +/- 0.00
# ExtraTreesRegressor                   0.04 +/- 0.01    0.08 +/- 0.01
# DecisionTreeRegressor                 0.05 +/- 0.01    0.01 +/- 0.00
# RANSACRegressor                       0.06 +/- 0.02    0.07 +/- 0.01
# LinearSVR                             0.06 +/- 0.03    0.02 +/- 0.01
# KNeighborsRegressor                   0.05 +/- 0.01    0.02 +/- 0.01
# LGBMRegressor                         0.05 +/- 0.01    0.40 +/- 0.03
# HuberRegressor                        0.06 +/- 0.03    0.04 +/- 0.00
# HistGradientBoostingRegressor         0.05 +/- 0.01    1.34 +/- 0.05
# PassiveAggressiveRegressor            0.08 +/- 0.04    0.01 +/- 0.01
# GammaRegressor                 6168.61 +/- 18504.46    0.01 +/- 0.00
# MLPRegressor                          0.13 +/- 0.11    0.05 +/- 0.03
#
#                                                             MAPE_media
# SVR                              1043414036729.47 +/- 1583347136039.85
# QuantileRegressor                  135176221154.91 +/- 205412993983.52
# GaussianProcessRegressor       14234400075465.40 +/- 34663722326635.12
# LassoLarsIC                        152659081191.66 +/- 249800076341.50
# SGDRegressor                       157718041499.48 +/- 263167016663.99
# OrthogonalMatchingPursuitCV        161262505346.04 +/- 287675041997.66
# KernelRidge                        161461519157.31 +/- 263953581198.28
# LinearRegression                   162253382638.30 +/- 265171657297.17
# TransformedTargetRegressor         162253382638.30 +/- 265171657297.17
# Lars                               162253382638.30 +/- 265171657297.17
# Ridge                              162505694150.71 +/- 265431355558.09
# BayesianRidge                      163020358787.77 +/- 266027914704.63
# RidgeCV                            164821462341.79 +/- 267915057110.38
# LarsCV                             164970996786.86 +/- 265686677940.17
# LassoLarsCV                        164970996786.86 +/- 265686677940.17
# LassoCV                            166243971410.99 +/- 266991177652.52
# ElasticNetCV                       166761550456.07 +/- 268071451484.83
# NuSVR                              182960347838.42 +/- 291703016088.08
# OrthogonalMatchingPursuit          188849769096.64 +/- 308574732127.91
# GradientBoostingRegressor          220653466794.18 +/- 348957159139.79
# TweedieRegressor                   232141568967.41 +/- 358189582885.21
# AdaBoostRegressor                  269435073906.60 +/- 438726335505.92
# XGBRegressor                       280221079883.01 +/- 480146983999.38
# PoissonRegressor                   350840183790.20 +/- 532856329652.90
# RandomForestRegressor              363239983492.42 +/- 603840701560.99
# ElasticNet                         366505422686.92 +/- 556623511700.21
# LassoLars                          366505422686.92 +/- 556623511700.21
# Lasso                              366505422686.92 +/- 556623511700.21
# DummyRegressor                     366505422686.92 +/- 556623511700.21
# BaggingRegressor                   373826472497.60 +/- 641486044304.91
# ExtraTreeRegressor                 416856314529.91 +/- 817753338526.65
# ExtraTreesRegressor                430342220444.43 +/- 707611555401.47
# DecisionTreeRegressor              471228877294.72 +/- 847469307798.71
# RANSACRegressor                      49740133094.30 +/- 89784293306.30
# LinearSVR                            50308920978.66 +/- 84608512422.89
# KNeighborsRegressor                524997300472.68 +/- 915405101917.93
# LGBMRegressor                      527163412875.04 +/- 846171771939.39
# HuberRegressor                       53325987096.26 +/- 82867995307.82
# HistGradientBoostingRegressor      538631878005.79 +/- 858810254342.02
# PassiveAggressiveRegressor        706831278030.39 +/- 1136189863922.29
# GammaRegressor                      734365302386.23 +/- 56369319665.01
# MLPRegressor                      910682633205.35 +/- 1385330766354.53

# %% [markdown]
# # Studio

# %%
results_dict = train(property_dfs,"Studio")

results_dict_format = {}

#imprime
for model in results_dict:
    results_dict_format[model]={}
    for metric in results_dict[model]:
        mean = np.mean(results_dict[model][metric]["mean"])
        std = np.std(results_dict[model][metric]["mean"])
        results_dict_format[model][metric + "_media"] = mean
        results_dict_format[model][metric + "_std"] = std

df = pd.DataFrame(results_dict_format)
df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
# Out:
# 100%|██████████| 42/42 [00:00<00:00, 45.91it/s]
# 100%|██████████| 42/42 [00:00<00:00, 46.95it/s]
# 100%|██████████| 42/42 [00:00<00:00, 47.13it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.97it/s]
# 100%|██████████| 42/42 [00:00<00:00, 46.33it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.38it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.97it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.34it/s]
# 100%|██████████| 42/42 [00:00<00:00, 47.31it/s]
# 100%|██████████| 42/42 [00:00<00:00, 54.18it/s]
# 100%|██████████| 42/42 [00:00<00:00, 46.99it/s]
# 100%|██████████| 42/42 [00:00<00:00, 51.86it/s]
# 100%|██████████| 42/42 [00:00<00:00, 53.35it/s]
# 100%|██████████| 42/42 [00:00<00:00, 50.81it/s]
# 100%|██████████| 42/42 [00:00<00:00, 51.24it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.92it/s]
# 100%|██████████| 42/42 [00:00<00:00, 49.42it/s]
# 100%|██████████| 42/42 [00:00<00:00, 46.45it/s]
# 100%|██████████| 42/42 [00:00<00:00, 55.34it/s]
# 100%|██████████| 42/42 [00:00<00:00, 42.28it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.52it/s]
# 100%|██████████| 42/42 [00:00<00:00, 51.39it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.03it/s]
# 100%|██████████| 42/42 [00:00<00:00, 49.80it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.48it/s]
# 100%|██████████| 42/42 [00:00<00:00, 53.00it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.49it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.87it/s]
# 100%|██████████| 42/42 [00:00<00:00, 46.92it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.00it/s]
# 100%|██████████| 42/42 [00:00<00:00, 45.45it/s]
# 100%|██████████| 42/42 [00:00<00:00, 54.32it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.77it/s]
#                                   Adjusted R-Squared_media  \
# KNeighborsRegressor                                  -1.73
# SVR                                                  -3.31
# QuantileRegressor                                    -3.32
# AdaBoostRegressor                                    -1.82
# XGBRegressor                                         -1.34
# RandomForestRegressor                                -1.60
# BaggingRegressor                                     -1.56
# GradientBoostingRegressor                            -2.13
# ExtraTreesRegressor                                  -1.88
# PassiveAggressiveRegressor                           -2.03
# GammaRegressor                                       -1.79
# GaussianProcessRegressor                             -5.39
# OrthogonalMatchingPursuit                            -1.33
# LassoLarsIC                                          -1.67
# DecisionTreeRegressor                                -3.42
# OrthogonalMatchingPursuitCV                          -2.06
# ExtraTreeRegressor                                   -3.15
# LassoLarsCV                                          -1.88
# LassoCV                                              -1.87
# LarsCV                                               -1.79
# ElasticNet                                           -2.13
# HuberRegressor                                       -3.18
# KernelRidge                                          -2.40
# BayesianRidge                                        -2.56
# Ridge                                                -2.56
# SGDRegressor                                         -2.67
# RidgeCV                                              -2.75
# TweedieRegressor                                     -2.40
# NuSVR                                                -4.21
# ElasticNetCV                                         -2.74
# LinearRegression                                     -3.21
# TransformedTargetRegressor                           -3.21
# LassoLars                                            -3.29
# Lasso                                                -3.29
# RANSACRegressor                                      -5.64
# LinearSVR                                            -7.13
# MLPRegressor                                         -7.57
# HistGradientBoostingRegressor                        -5.18
# DummyRegressor                                       -5.18
# LGBMRegressor                                        -5.18
# PoissonRegressor                                 -10230.94
# Lars                          -140206597758299764948992.00
#
#                                    Adjusted R-Squared_std  \
# KNeighborsRegressor                                  1.44
# SVR                                                  0.42
# QuantileRegressor                                    0.42
# AdaBoostRegressor                                    1.93
# XGBRegressor                                         2.07
# RandomForestRegressor                                1.69
# BaggingRegressor                                     1.47
# GradientBoostingRegressor                            2.91
# ExtraTreesRegressor                                  3.32
# PassiveAggressiveRegressor                           3.66
# GammaRegressor                                       2.45
# GaussianProcessRegressor                             1.22
# OrthogonalMatchingPursuit                            1.86
# LassoLarsIC                                          3.89
# DecisionTreeRegressor                                4.99
# OrthogonalMatchingPursuitCV                          4.60
# ExtraTreeRegressor                                   3.02
# LassoLarsCV                                          3.86
# LassoCV                                              3.82
# LarsCV                                               3.69
# ElasticNet                                           4.80
# HuberRegressor                                       6.20
# KernelRidge                                          6.06
# BayesianRidge                                        5.86
# Ridge                                                6.31
# SGDRegressor                                         6.74
# RidgeCV                                              6.23
# TweedieRegressor                                     5.06
# NuSVR                                                5.21
# ElasticNetCV                                         5.74
# LinearRegression                                     7.26
# TransformedTargetRegressor                           7.26
# LassoLars                                            7.28
# Lasso                                                7.28
# RANSACRegressor                                      5.65
# LinearSVR                                            3.95
# MLPRegressor                                         4.64
# HistGradientBoostingRegressor                        9.39
# DummyRegressor                                       9.39
# LGBMRegressor                                        9.39
# PoissonRegressor                                 36531.16
# Lars                          510751594004142132035584.00
#
#                                           R-Squared_media  \
# KNeighborsRegressor                                  0.22
# SVR                                                 -0.23
# QuantileRegressor                                   -0.23
# AdaBoostRegressor                                    0.19
# XGBRegressor                                         0.33
# RandomForestRegressor                                0.26
# BaggingRegressor                                     0.27
# GradientBoostingRegressor                            0.11
# ExtraTreesRegressor                                  0.18
# PassiveAggressiveRegressor                           0.13
# GammaRegressor                                       0.20
# GaussianProcessRegressor                            -0.83
# OrthogonalMatchingPursuit                            0.33
# LassoLarsIC                                          0.24
# DecisionTreeRegressor                               -0.26
# OrthogonalMatchingPursuitCV                          0.13
# ExtraTreeRegressor                                  -0.19
# LassoLarsCV                                          0.18
# LassoCV                                              0.18
# LarsCV                                               0.20
# ElasticNet                                           0.10
# HuberRegressor                                      -0.19
# KernelRidge                                          0.03
# BayesianRidge                                       -0.02
# Ridge                                               -0.02
# SGDRegressor                                        -0.05
# RidgeCV                                             -0.07
# TweedieRegressor                                     0.03
# NuSVR                                               -0.49
# ElasticNetCV                                        -0.07
# LinearRegression                                    -0.20
# TransformedTargetRegressor                          -0.20
# LassoLars                                           -0.22
# Lasso                                               -0.22
# RANSACRegressor                                     -0.90
# LinearSVR                                           -1.32
# MLPRegressor                                        -1.45
# HistGradientBoostingRegressor                       -0.76
# DummyRegressor                                      -0.76
# LGBMRegressor                                       -0.76
# PoissonRegressor                                 -2922.41
# Lars                          -40059027930942785191936.00
#
#                                             R-Squared_std         RMSE_media  \
# KNeighborsRegressor                                  0.41            1847.10
# SVR                                                  0.12            2322.84
# QuantileRegressor                                    0.12            2324.00
# AdaBoostRegressor                                    0.55            1687.82
# XGBRegressor                                         0.59            1512.97
# RandomForestRegressor                                0.48            1643.14
# BaggingRegressor                                     0.42            1639.39
# GradientBoostingRegressor                            0.83            1583.86
# ExtraTreesRegressor                                  0.95            1570.33
# PassiveAggressiveRegressor                           1.05            1612.77
# GammaRegressor                                       0.70            1709.97
# GaussianProcessRegressor                             0.35            2739.85
# OrthogonalMatchingPursuit                            0.53            1439.03
# LassoLarsIC                                          1.11            1394.98
# DecisionTreeRegressor                                1.43            1783.31
# OrthogonalMatchingPursuitCV                          1.31            1443.55
# ExtraTreeRegressor                                   0.86            1986.77
# LassoLarsCV                                          1.10            1489.54
# LassoCV                                              1.09            1493.87
# LarsCV                                               1.05            1494.46
# ElasticNet                                           1.37            1597.15
# HuberRegressor                                       1.77            1622.25
# KernelRidge                                          1.73            1422.55
# BayesianRidge                                        1.67            1553.98
# Ridge                                                1.80            1444.62
# SGDRegressor                                         1.92            1466.25
# RidgeCV                                              1.78            1617.82
# TweedieRegressor                                     1.45            1719.76
# NuSVR                                                1.49            2283.71
# ElasticNetCV                                         1.64            1789.66
# LinearRegression                                     2.08            1589.63
# TransformedTargetRegressor                           2.08            1589.63
# LassoLars                                            2.08            1593.99
# Lasso                                                2.08            1594.11
# RANSACRegressor                                      1.61            2328.61
# LinearSVR                                            1.13            2881.74
# MLPRegressor                                         1.33            2927.63
# HistGradientBoostingRegressor                        2.68            2258.20
# DummyRegressor                                       2.68            2258.20
# LGBMRegressor                                        2.68            2258.20
# PoissonRegressor                                 10437.47           57704.64
# Lars                          145929026858326318645248.00 174212812679030.50
#
#                                         RMSE_std  Time Taken_media  \
# KNeighborsRegressor                       989.23              0.01
# SVR                                      1032.87              0.01
# QuantileRegressor                        1032.92              0.02
# AdaBoostRegressor                         807.63              0.07
# XGBRegressor                              791.11              0.16
# RandomForestRegressor                     783.72              0.05
# BaggingRegressor                          757.92              0.01
# GradientBoostingRegressor                 685.31              0.03
# ExtraTreesRegressor                       707.80              0.04
# PassiveAggressiveRegressor                767.19              0.01
# GammaRegressor                            795.19              0.01
# GaussianProcessRegressor                 1114.49              0.01
# OrthogonalMatchingPursuit                 719.19              0.01
# LassoLarsIC                               551.62              0.01
# DecisionTreeRegressor                     703.14              0.01
# OrthogonalMatchingPursuitCV               617.34              0.01
# ExtraTreeRegressor                        793.27              0.01
# LassoLarsCV                               603.49              0.01
# LassoCV                                   607.61              0.03
# LarsCV                                    617.66              0.01
# ElasticNet                                664.07              0.01
# HuberRegressor                            541.86              0.03
# KernelRidge                               424.09              0.01
# BayesianRidge                             537.73              0.01
# Ridge                                     417.41              0.01
# SGDRegressor                              436.47              0.01
# RidgeCV                                   577.28              0.01
# TweedieRegressor                          743.30              0.01
# NuSVR                                     936.36              0.01
# ElasticNetCV                              733.76              0.03
# LinearRegression                          485.07              0.01
# TransformedTargetRegressor                485.07              0.01
# LassoLars                                 475.16              0.01
# Lasso                                     475.18              0.01
# RANSACRegressor                          1020.02              0.05
# LinearSVR                                1003.78              0.01
# MLPRegressor                              997.61              0.03
# HistGradientBoostingRegressor             822.92              0.05
# DummyRegressor                            822.92              0.01
# LGBMRegressor                             822.92              0.03
# PoissonRegressor                       157425.21              0.02
# Lars                          597385448180239.62              0.01
#
#                                Time Taken_std  \
# KNeighborsRegressor                      0.00
# SVR                                      0.00
# QuantileRegressor                        0.01
# AdaBoostRegressor                        0.01
# XGBRegressor                             0.04
# RandomForestRegressor                    0.01
# BaggingRegressor                         0.00
# GradientBoostingRegressor                0.01
# ExtraTreesRegressor                      0.00
# PassiveAggressiveRegressor               0.00
# GammaRegressor                           0.00
# GaussianProcessRegressor                 0.00
# OrthogonalMatchingPursuit                0.00
# LassoLarsIC                              0.00
# DecisionTreeRegressor                    0.00
# OrthogonalMatchingPursuitCV              0.00
# ExtraTreeRegressor                       0.00
# LassoLarsCV                              0.00
# LassoCV                                  0.01
# LarsCV                                   0.00
# ElasticNet                               0.00
# HuberRegressor                           0.01
# KernelRidge                              0.00
# BayesianRidge                            0.00
# Ridge                                    0.00
# SGDRegressor                             0.00
# RidgeCV                                  0.00
# TweedieRegressor                         0.00
# NuSVR                                    0.00
# ElasticNetCV                             0.01
# LinearRegression                         0.00
# TransformedTargetRegressor               0.00
# LassoLars                                0.00
# Lasso                                    0.00
# RANSACRegressor                          0.01
# LinearSVR                                0.00
# MLPRegressor                             0.00
# HistGradientBoostingRegressor            0.02
# DummyRegressor                           0.00
# LGBMRegressor                            0.00
# PoissonRegressor                         0.01
# Lars                                     0.00
#
#                                mean_absolute_percentage_error_media  \
# KNeighborsRegressor                                            0.37
# SVR                                                            0.42
# QuantileRegressor                                              0.42
# AdaBoostRegressor                                              0.46
# XGBRegressor                                                   0.46
# RandomForestRegressor                                          0.49
# BaggingRegressor                                               0.50
# GradientBoostingRegressor                                      0.52
# ExtraTreesRegressor                                            0.52
# PassiveAggressiveRegressor                                     0.56
# GammaRegressor                                                 0.56
# GaussianProcessRegressor                                       0.56
# OrthogonalMatchingPursuit                                      0.56
# LassoLarsIC                                                    0.57
# DecisionTreeRegressor                                          0.60
# OrthogonalMatchingPursuitCV                                    0.61
# ExtraTreeRegressor                                             0.61
# LassoLarsCV                                                    0.62
# LassoCV                                                        0.62
# LarsCV                                                         0.63
# ElasticNet                                                     0.64
# HuberRegressor                                                 0.65
# KernelRidge                                                    0.65
# BayesianRidge                                                  0.66
# Ridge                                                          0.67
# SGDRegressor                                                   0.67
# RidgeCV                                                        0.67
# TweedieRegressor                                               0.68
# NuSVR                                                          0.72
# ElasticNetCV                                                   0.73
# LinearRegression                                               0.73
# TransformedTargetRegressor                                     0.73
# LassoLars                                                      0.74
# Lasso                                                          0.74
# RANSACRegressor                                                0.83
# LinearSVR                                                      0.92
# MLPRegressor                                                   0.98
# HistGradientBoostingRegressor                                  1.01
# DummyRegressor                                                 1.01
# LGBMRegressor                                                  1.01
# PoissonRegressor                                               2.12
# Lars                                                 62952911600.40
#
#                                mean_absolute_percentage_error_std
# KNeighborsRegressor                                          0.10
# SVR                                                          0.08
# QuantileRegressor                                            0.08
# AdaBoostRegressor                                            0.16
# XGBRegressor                                                 0.14
# RandomForestRegressor                                        0.16
# BaggingRegressor                                             0.17
# GradientBoostingRegressor                                    0.21
# ExtraTreesRegressor                                          0.16
# PassiveAggressiveRegressor                                   0.14
# GammaRegressor                                               0.13
# GaussianProcessRegressor                                     0.10
# OrthogonalMatchingPursuit                                    0.11
# LassoLarsIC                                                  0.14
# DecisionTreeRegressor                                        0.18
# OrthogonalMatchingPursuitCV                                  0.15
# ExtraTreeRegressor                                           0.22
# LassoLarsCV                                                  0.16
# LassoCV                                                      0.16
# LarsCV                                                       0.16
# ElasticNet                                                   0.17
# HuberRegressor                                               0.18
# KernelRidge                                                  0.16
# BayesianRidge                                                0.17
# Ridge                                                        0.17
# SGDRegressor                                                 0.17
# RidgeCV                                                      0.17
# TweedieRegressor                                             0.18
# NuSVR                                                        0.22
# ElasticNetCV                                                 0.20
# LinearRegression                                             0.16
# TransformedTargetRegressor                                   0.16
# LassoLars                                                    0.18
# Lasso                                                        0.18
# RANSACRegressor                                              0.31
# LinearSVR                                                    0.01
# MLPRegressor                                                 0.00
# HistGradientBoostingRegressor                                0.24
# DummyRegressor                                               0.24
# LGBMRegressor                                                0.24
# PoissonRegressor                                             4.14
# Lars                                              218991249945.37

# %% [markdown]
# # Galpão

# %%
results_dict = train(property_dfs,"Galpão")

results_dict_format = {}

#imprime
for model in results_dict:
    results_dict_format[model]={}
    for metric in results_dict[model]:
        mean = np.mean(results_dict[model][metric]["mean"])
        std = np.std(results_dict[model][metric]["mean"])
        results_dict_format[model][metric + "_media"] = mean
        results_dict_format[model][metric + "_std"] = std

df = pd.DataFrame(results_dict_format)
df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.02it/s]
# 100%|██████████| 42/42 [00:00<00:00, 45.72it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.08it/s]
# 100%|██████████| 42/42 [00:00<00:00, 45.70it/s]
# 100%|██████████| 42/42 [00:00<00:00, 54.17it/s]
# 100%|██████████| 42/42 [00:00<00:00, 64.35it/s]
# 100%|██████████| 42/42 [00:00<00:00, 64.33it/s]
# 100%|██████████| 42/42 [00:00<00:00, 60.67it/s]
# 100%|██████████| 42/42 [00:00<00:00, 54.86it/s]
# 100%|██████████| 42/42 [00:00<00:00, 51.05it/s]
# 100%|██████████| 42/42 [00:00<00:00, 42.80it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.80it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.52it/s]
# 100%|██████████| 42/42 [00:00<00:00, 53.50it/s]
# 100%|██████████| 42/42 [00:01<00:00, 40.91it/s]
# 100%|██████████| 42/42 [00:00<00:00, 52.50it/s]
# 100%|██████████| 42/42 [00:00<00:00, 42.38it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.51it/s]
# 100%|██████████| 42/42 [00:00<00:00, 45.95it/s]
# 100%|██████████| 42/42 [00:00<00:00, 60.15it/s]
# 100%|██████████| 42/42 [00:00<00:00, 52.44it/s]
# 100%|██████████| 42/42 [00:00<00:00, 49.67it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.49it/s]
# 100%|██████████| 42/42 [00:00<00:00, 57.33it/s]
# 100%|██████████| 42/42 [00:00<00:00, 58.10it/s]
# 100%|██████████| 42/42 [00:00<00:00, 57.14it/s]
# 100%|██████████| 42/42 [00:00<00:00, 50.34it/s]
# 100%|██████████| 42/42 [00:00<00:00, 52.46it/s]
# 100%|██████████| 42/42 [00:00<00:00, 56.00it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.57it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.51it/s]
# 100%|██████████| 42/42 [00:00<00:00, 53.51it/s]
# 100%|██████████| 42/42 [00:00<00:00, 47.97it/s]
#                                                       Adjusted R-Squared_media  \
# SVR                                                                      10.91
# LinearSVR                                                                14.06
# QuantileRegressor                                                        10.99
# MLPRegressor                                                             14.18
# RANSACRegressor                                                          14.54
# PassiveAggressiveRegressor                                               14.95
# NuSVR                                                                    14.26
# HuberRegressor                                                           22.63
# AdaBoostRegressor                                                        44.15
# GaussianProcessRegressor                                                242.47
# LarsCV                                                                   38.54
# LassoCV                                                                  39.51
# OrthogonalMatchingPursuitCV                                              51.55
# LassoLarsCV                                                              39.50
# BayesianRidge                                                            48.83
# LassoLarsIC                                                              48.83
# ElasticNet                                                               51.19
# KNeighborsRegressor                                                      72.03
# RidgeCV                                                                  51.42
# OrthogonalMatchingPursuit                                                44.69
# TweedieRegressor                                                         57.02
# KernelRidge                                                              51.66
# Ridge                                                                    55.88
# SGDRegressor                                                             64.47
# RandomForestRegressor                                                   170.76
# Lasso                                                                   165.93
# LassoLars                                                               165.94
# TransformedTargetRegressor                                              167.01
# LinearRegression                                                        167.01
# BaggingRegressor                                                        138.83
# XGBRegressor                                                            445.70
# ExtraTreesRegressor                                                     200.44
# GradientBoostingRegressor                                               371.03
# DecisionTreeRegressor                                                   627.73
# Lars                                                                    192.27
# ElasticNetCV                                                            121.13
# HistGradientBoostingRegressor                                           146.92
# LGBMRegressor                                                           146.92
# DummyRegressor                                                          146.92
# ExtraTreeRegressor                                                      633.71
# GammaRegressor                                   66981367144125347460546560.00
# PoissonRegressor              295722485330148081829889335066803427761717248.00
#
#                                                          Adjusted R-Squared_std  \
# SVR                                                                        1.39
# LinearSVR                                                                  6.37
# QuantileRegressor                                                          1.79
# MLPRegressor                                                               6.72
# RANSACRegressor                                                           25.06
# PassiveAggressiveRegressor                                                36.61
# NuSVR                                                                     15.83
# HuberRegressor                                                            63.26
# AdaBoostRegressor                                                        145.78
# GaussianProcessRegressor                                                 721.66
# LarsCV                                                                    78.07
# LassoCV                                                                   77.78
# OrthogonalMatchingPursuitCV                                              116.30
# LassoLarsCV                                                               77.77
# BayesianRidge                                                             95.10
# LassoLarsIC                                                              118.26
# ElasticNet                                                               100.31
# KNeighborsRegressor                                                      161.17
# RidgeCV                                                                  100.23
# OrthogonalMatchingPursuit                                                112.40
# TweedieRegressor                                                         118.09
# KernelRidge                                                               79.84
# Ridge                                                                     89.54
# SGDRegressor                                                             101.35
# RandomForestRegressor                                                    474.62
# Lasso                                                                    439.14
# LassoLars                                                                439.18
# TransformedTargetRegressor                                               442.41
# LinearRegression                                                         442.41
# BaggingRegressor                                                         307.73
# XGBRegressor                                                            1391.32
# ExtraTreesRegressor                                                      524.25
# GradientBoostingRegressor                                               1360.27
# DecisionTreeRegressor                                                   2524.86
# Lars                                                                     468.91
# ElasticNetCV                                                             320.24
# HistGradientBoostingRegressor                                            404.79
# LGBMRegressor                                                            404.79
# DummyRegressor                                                           404.79
# ExtraTreeRegressor                                                      1598.12
# GammaRegressor                                   378903806969188073521283072.00
# PoissonRegressor              1672858997810296053009106322300569458915147776.00
#
#                                                                R-Squared_media  \
# SVR                                                                      -0.24
# LinearSVR                                                                -0.63
# QuantileRegressor                                                        -0.25
# MLPRegressor                                                             -0.65
# RANSACRegressor                                                          -0.69
# PassiveAggressiveRegressor                                               -0.74
# NuSVR                                                                    -0.66
# HuberRegressor                                                           -1.70
# AdaBoostRegressor                                                        -4.39
# GaussianProcessRegressor                                                -29.18
# LarsCV                                                                   -3.69
# LassoCV                                                                  -3.81
# OrthogonalMatchingPursuitCV                                              -5.32
# LassoLarsCV                                                              -3.81
# BayesianRidge                                                            -4.98
# LassoLarsIC                                                              -4.98
# ElasticNet                                                               -5.27
# KNeighborsRegressor                                                      -7.88
# RidgeCV                                                                  -5.30
# OrthogonalMatchingPursuit                                                -4.46
# TweedieRegressor                                                         -6.00
# KernelRidge                                                              -5.33
# Ridge                                                                    -5.86
# SGDRegressor                                                             -6.93
# RandomForestRegressor                                                   -20.22
# Lasso                                                                   -19.62
# LassoLars                                                               -19.62
# TransformedTargetRegressor                                              -19.75
# LinearRegression                                                        -19.75
# BaggingRegressor                                                        -16.23
# XGBRegressor                                                            -54.59
# ExtraTreesRegressor                                                     -23.93
# GradientBoostingRegressor                                               -45.25
# DecisionTreeRegressor                                                   -77.34
# Lars                                                                    -22.91
# ElasticNetCV                                                            -14.02
# HistGradientBoostingRegressor                                           -17.24
# LGBMRegressor                                                           -17.24
# DummyRegressor                                                          -17.24
# ExtraTreeRegressor                                                      -78.09
# GammaRegressor                                   -8372670893015668432568320.00
# PoissonRegressor              -36965310666268510228736166883350428470214656.00
#
#                                                                  R-Squared_std  \
# SVR                                                                       0.17
# LinearSVR                                                                 0.80
# QuantileRegressor                                                         0.22
# MLPRegressor                                                              0.84
# RANSACRegressor                                                           3.13
# PassiveAggressiveRegressor                                                4.58
# NuSVR                                                                     1.98
# HuberRegressor                                                            7.91
# AdaBoostRegressor                                                        18.22
# GaussianProcessRegressor                                                 90.21
# LarsCV                                                                    9.76
# LassoCV                                                                   9.72
# OrthogonalMatchingPursuitCV                                              14.54
# LassoLarsCV                                                               9.72
# BayesianRidge                                                            11.89
# LassoLarsIC                                                              14.78
# ElasticNet                                                               12.54
# KNeighborsRegressor                                                      20.15
# RidgeCV                                                                  12.53
# OrthogonalMatchingPursuit                                                14.05
# TweedieRegressor                                                         14.76
# KernelRidge                                                               9.98
# Ridge                                                                    11.19
# SGDRegressor                                                             12.67
# RandomForestRegressor                                                    59.33
# Lasso                                                                    54.89
# LassoLars                                                                54.90
# TransformedTargetRegressor                                               55.30
# LinearRegression                                                         55.30
# BaggingRegressor                                                         38.47
# XGBRegressor                                                            173.91
# ExtraTreesRegressor                                                      65.53
# GradientBoostingRegressor                                               170.03
# DecisionTreeRegressor                                                   315.61
# Lars                                                                     58.61
# ElasticNetCV                                                             40.03
# HistGradientBoostingRegressor                                            50.60
# LGBMRegressor                                                            50.60
# DummyRegressor                                                           50.60
# ExtraTreeRegressor                                                      199.77
# GammaRegressor                                   47362975871148509190160384.00
# PoissonRegressor              209107374726287006626138290287571182364393472.00
#
#                                                  RMSE_media  \
# SVR                                                13686.04
# LinearSVR                                          14149.36
# QuantileRegressor                                  13666.09
# MLPRegressor                                       14131.74
# RANSACRegressor                                    12267.24
# PassiveAggressiveRegressor                         11097.55
# NuSVR                                              13561.15
# HuberRegressor                                     12960.75
# AdaBoostRegressor                                  13474.27
# GaussianProcessRegressor                           16908.76
# LarsCV                                             13555.97
# LassoCV                                            13709.51
# OrthogonalMatchingPursuitCV                        13113.38
# LassoLarsCV                                        13717.18
# BayesianRidge                                      13626.21
# LassoLarsIC                                        13562.56
# ElasticNet                                         13698.83
# KNeighborsRegressor                                14758.51
# RidgeCV                                            13932.78
# OrthogonalMatchingPursuit                          13346.93
# TweedieRegressor                                   12876.97
# KernelRidge                                        19387.17
# Ridge                                              19429.45
# SGDRegressor                                       21921.99
# RandomForestRegressor                              15357.98
# Lasso                                              23948.30
# LassoLars                                          23948.84
# TransformedTargetRegressor                         23981.55
# LinearRegression                                   23981.55
# BaggingRegressor                                   15665.97
# XGBRegressor                                       17548.00
# ExtraTreesRegressor                                15346.94
# GradientBoostingRegressor                          17372.02
# DecisionTreeRegressor                              19211.99
# Lars                                               29227.61
# ElasticNetCV                                       14108.47
# HistGradientBoostingRegressor                      15012.01
# LGBMRegressor                                      15012.01
# DummyRegressor                                     15012.01
# ExtraTreeRegressor                                 18866.96
# GammaRegressor                         13089253877594460.00
# PoissonRegressor              30030251754786759014088704.00
#
#                                                     RMSE_std  \
# SVR                                                 10366.97
# LinearSVR                                           10329.43
# QuantileRegressor                                   10362.10
# MLPRegressor                                        10282.04
# RANSACRegressor                                      9577.72
# PassiveAggressiveRegressor                           8106.82
# NuSVR                                               10250.98
# HuberRegressor                                       9914.28
# AdaBoostRegressor                                    9363.44
# GaussianProcessRegressor                             7940.98
# LarsCV                                               8678.68
# LassoCV                                              8528.06
# OrthogonalMatchingPursuitCV                          7702.51
# LassoLarsCV                                          8537.99
# BayesianRidge                                        8085.63
# LassoLarsIC                                          8526.95
# ElasticNet                                          10805.74
# KNeighborsRegressor                                  8145.62
# RidgeCV                                             10883.00
# OrthogonalMatchingPursuit                            8368.92
# TweedieRegressor                                     8559.59
# KernelRidge                                         24596.61
# Ridge                                               24528.56
# SGDRegressor                                        30349.07
# RandomForestRegressor                                7404.54
# Lasso                                               32896.49
# LassoLars                                           32896.49
# TransformedTargetRegressor                          32944.53
# LinearRegression                                    32944.53
# BaggingRegressor                                     7412.96
# XGBRegressor                                         8644.04
# ExtraTreesRegressor                                  7419.76
# GradientBoostingRegressor                            6889.34
# DecisionTreeRegressor                                8018.27
# Lars                                                53741.70
# ElasticNetCV                                         7036.94
# HistGradientBoostingRegressor                        7796.59
# LGBMRegressor                                        7796.59
# DummyRegressor                                       7796.59
# ExtraTreeRegressor                                   7803.51
# GammaRegressor                          74023056979797808.00
# PoissonRegressor              169876757107407017169911808.00
#
#                                Time Taken_media  Time Taken_std  \
# SVR                                        0.01            0.00
# LinearSVR                                  0.01            0.00
# QuantileRegressor                          0.02            0.01
# MLPRegressor                               0.03            0.01
# RANSACRegressor                            0.04            0.02
# PassiveAggressiveRegressor                 0.01            0.00
# NuSVR                                      0.01            0.00
# HuberRegressor                             0.02            0.01
# AdaBoostRegressor                          0.06            0.02
# GaussianProcessRegressor                   0.01            0.00
# LarsCV                                     0.01            0.00
# LassoCV                                    0.03            0.00
# OrthogonalMatchingPursuitCV                0.01            0.00
# LassoLarsCV                                0.01            0.00
# BayesianRidge                              0.01            0.00
# LassoLarsIC                                0.01            0.00
# ElasticNet                                 0.01            0.00
# KNeighborsRegressor                        0.01            0.01
# RidgeCV                                    0.01            0.00
# OrthogonalMatchingPursuit                  0.01            0.00
# TweedieRegressor                           0.01            0.00
# KernelRidge                                0.01            0.00
# Ridge                                      0.01            0.00
# SGDRegressor                               0.01            0.00
# RandomForestRegressor                      0.05            0.01
# Lasso                                      0.01            0.00
# LassoLars                                  0.01            0.00
# TransformedTargetRegressor                 0.01            0.00
# LinearRegression                           0.01            0.00
# BaggingRegressor                           0.01            0.00
# XGBRegressor                               0.14            0.05
# ExtraTreesRegressor                        0.04            0.00
# GradientBoostingRegressor                  0.03            0.01
# DecisionTreeRegressor                      0.01            0.00
# Lars                                       0.01            0.00
# ElasticNetCV                               0.03            0.00
# HistGradientBoostingRegressor              0.06            0.03
# LGBMRegressor                              0.03            0.01
# DummyRegressor                             0.01            0.00
# ExtraTreeRegressor                         0.01            0.00
# GammaRegressor                             0.01            0.00
# PoissonRegressor                           0.02            0.01
#
#                                mean_absolute_percentage_error_media  \
# SVR                                                            0.90
# LinearSVR                                                      0.96
# QuantileRegressor                                              0.96
# MLPRegressor                                                   0.99
# RANSACRegressor                                                1.25
# PassiveAggressiveRegressor                                     1.28
# NuSVR                                                          1.45
# HuberRegressor                                                 1.51
# AdaBoostRegressor                                              1.68
# GaussianProcessRegressor                                       2.69
# LarsCV                                                         3.04
# LassoCV                                                        3.17
# OrthogonalMatchingPursuitCV                                    3.18
# LassoLarsCV                                                    3.18
# BayesianRidge                                                  3.19
# LassoLarsIC                                                    3.27
# ElasticNet                                                     3.41
# KNeighborsRegressor                                            3.46
# RidgeCV                                                        3.46
# OrthogonalMatchingPursuit                                      3.46
# TweedieRegressor                                               3.53
# KernelRidge                                                    3.83
# Ridge                                                          3.96
# SGDRegressor                                                   4.27
# RandomForestRegressor                                          4.84
# Lasso                                                          4.96
# LassoLars                                                      4.96
# TransformedTargetRegressor                                     4.97
# LinearRegression                                               4.97
# BaggingRegressor                                               5.00
# XGBRegressor                                                   5.33
# ExtraTreesRegressor                                            5.34
# GradientBoostingRegressor                                      5.57
# DecisionTreeRegressor                                          5.87
# Lars                                                           5.98
# ElasticNetCV                                                   6.41
# HistGradientBoostingRegressor                                  7.24
# LGBMRegressor                                                  7.24
# DummyRegressor                                                 7.24
# ExtraTreeRegressor                                             8.01
# GammaRegressor                                       51330407365.42
# PoissonRegressor                           117765693156026515456.00
#
#                                mean_absolute_percentage_error_std
# SVR                                                          0.56
# LinearSVR                                                    0.01
# QuantileRegressor                                            0.55
# MLPRegressor                                                 0.00
# RANSACRegressor                                              0.83
# PassiveAggressiveRegressor                                   0.91
# NuSVR                                                        0.73
# HuberRegressor                                               1.15
# AdaBoostRegressor                                            2.68
# GaussianProcessRegressor                                     2.43
# LarsCV                                                       1.94
# LassoCV                                                      2.03
# OrthogonalMatchingPursuitCV                                  1.80
# LassoLarsCV                                                  2.03
# BayesianRidge                                                1.75
# LassoLarsIC                                                  2.15
# ElasticNet                                                   2.14
# KNeighborsRegressor                                          3.06
# RidgeCV                                                      2.18
# OrthogonalMatchingPursuit                                    1.87
# TweedieRegressor                                             1.95
# KernelRidge                                                  3.54
# Ridge                                                        3.64
# SGDRegressor                                                 4.29
# RandomForestRegressor                                        5.58
# Lasso                                                        4.72
# LassoLars                                                    4.72
# TransformedTargetRegressor                                   4.72
# LinearRegression                                             4.72
# BaggingRegressor                                             7.07
# XGBRegressor                                                10.63
# ExtraTreesRegressor                                          8.32
# GradientBoostingRegressor                                    8.99
# DecisionTreeRegressor                                       10.67
# Lars                                                         9.27
# ElasticNetCV                                                 2.94
# HistGradientBoostingRegressor                                3.39
# LGBMRegressor                                                3.39
# DummyRegressor                                               3.39
# ExtraTreeRegressor                                          13.16
# GammaRegressor                                    290286497960.37
# PoissonRegressor                         666183361205517680640.00

# %% [markdown]
# # Casa

# %%
results_dict = train(property_dfs,"Casa")

results_dict_format = {}

#imprime
for model in results_dict:
    results_dict_format[model]={}
    for metric in results_dict[model]:
        mean = np.mean(results_dict[model][metric]["mean"])
        std = np.std(results_dict[model][metric]["mean"])
        results_dict_format[model][metric + "_media"] = mean
        results_dict_format[model][metric + "_std"] = std

df = pd.DataFrame(results_dict_format)
df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
# Out:
# 100%|██████████| 42/42 [00:00<00:00, 42.49it/s]
# 100%|██████████| 42/42 [00:01<00:00, 37.71it/s]
# 100%|██████████| 42/42 [00:01<00:00, 37.38it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.60it/s]
# 100%|██████████| 42/42 [00:01<00:00, 38.03it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.80it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.73it/s]
# 100%|██████████| 42/42 [00:01<00:00, 36.32it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.48it/s]
# 100%|██████████| 42/42 [00:01<00:00, 40.62it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.42it/s]
# 100%|██████████| 42/42 [00:00<00:00, 42.19it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.07it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.04it/s]
# 100%|██████████| 42/42 [00:00<00:00, 49.17it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.23it/s]
# 100%|██████████| 42/42 [00:00<00:00, 47.01it/s]
# 100%|██████████| 42/42 [00:00<00:00, 42.94it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.38it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.53it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.67it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.51it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.62it/s]
# 100%|██████████| 42/42 [00:00<00:00, 47.32it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.10it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.41it/s]
# 100%|██████████| 42/42 [00:01<00:00, 38.15it/s]
# 100%|██████████| 42/42 [00:01<00:00, 40.83it/s]
# 100%|██████████| 42/42 [00:00<00:00, 45.95it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.89it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.95it/s]
# 100%|██████████| 42/42 [00:00<00:00, 46.19it/s]
# 100%|██████████| 42/42 [00:01<00:00, 37.42it/s]
#                                Adjusted R-Squared_media  \
# ExtraTreesRegressor                                0.34
# RandomForestRegressor                              0.34
# BaggingRegressor                                   0.29
# KNeighborsRegressor                               -0.43
# GradientBoostingRegressor                          0.19
# XGBRegressor                                       0.30
# AdaBoostRegressor                                  0.26
# PassiveAggressiveRegressor                        -0.15
# DecisionTreeRegressor                             -0.31
# SVR                                               -1.04
# QuantileRegressor                                 -1.04
# HuberRegressor                                    -0.49
# ExtraTreeRegressor                                -0.46
# GaussianProcessRegressor                          -1.97
# GammaRegressor                                   -13.88
# RANSACRegressor                                   -1.66
# NuSVR                                             -1.01
# ElasticNet                                        -0.48
# RidgeCV                                           -1.02
# TweedieRegressor                                  -0.25
# BayesianRidge                                     -1.55
# KernelRidge                                       -2.60
# ElasticNetCV                                      -0.18
# LassoLarsIC                                       -2.54
# SGDRegressor                                      -2.23
# Ridge                                             -2.64
# Lasso                                             -3.46
# LassoLars                                         -3.46
# TransformedTargetRegressor                        -3.51
# LinearRegression                                  -3.51
# OrthogonalMatchingPursuitCV                       -3.54
# OrthogonalMatchingPursuit                         -4.81
# LassoLarsCV                                       -1.98
# LassoCV                                           -1.96
# LarsCV                                            -1.98
# Lars                                             -17.12
# HistGradientBoostingRegressor                     -0.66
# LGBMRegressor                                     -0.68
# LinearSVR                                         -2.91
# DummyRegressor                                    -1.21
# MLPRegressor                                      -3.15
# PoissonRegressor                               -1879.08
#
#                                Adjusted R-Squared_std  R-Squared_media  \
# ExtraTreesRegressor                              0.62             0.62
# RandomForestRegressor                            0.41             0.62
# BaggingRegressor                                 0.37             0.60
# KNeighborsRegressor                              0.84             0.18
# GradientBoostingRegressor                        0.56             0.54
# XGBRegressor                                     0.66             0.60
# AdaBoostRegressor                                0.44             0.58
# PassiveAggressiveRegressor                       0.97             0.34
# DecisionTreeRegressor                            1.53             0.25
# SVR                                              0.19            -0.17
# QuantileRegressor                                0.19            -0.17
# HuberRegressor                                   1.62             0.15
# ExtraTreeRegressor                               1.23             0.16
# GaussianProcessRegressor                         0.59            -0.70
# GammaRegressor                                  51.36            -7.50
# RANSACRegressor                                  2.69            -0.52
# NuSVR                                            0.42            -0.15
# ElasticNet                                       1.17             0.15
# RidgeCV                                          1.90            -0.15
# TweedieRegressor                                 0.80             0.29
# BayesianRidge                                    2.73            -0.46
# KernelRidge                                      3.88            -1.06
# ElasticNetCV                                     0.71             0.32
# LassoLarsIC                                      4.13            -1.02
# SGDRegressor                                     3.32            -0.84
# Ridge                                            3.91            -1.08
# Lasso                                            5.02            -1.55
# LassoLars                                        5.02            -1.55
# TransformedTargetRegressor                       5.08            -1.58
# LinearRegression                                 5.08            -1.58
# OrthogonalMatchingPursuitCV                      5.11            -1.60
# OrthogonalMatchingPursuit                        8.68            -2.32
# LassoLarsCV                                      3.23            -0.70
# LassoCV                                          3.25            -0.69
# LarsCV                                           3.23            -0.70
# Lars                                            79.37            -9.35
# HistGradientBoostingRegressor                    1.39             0.05
# LGBMRegressor                                    1.54             0.04
# LinearSVR                                        1.32            -1.23
# DummyRegressor                                   1.08            -0.26
# MLPRegressor                                     1.55            -1.37
# PoissonRegressor                              8427.94         -1073.33
#
#                                R-Squared_std  RMSE_media  RMSE_std  \
# ExtraTreesRegressor                     0.36      923.80    483.75
# RandomForestRegressor                   0.23      942.49    418.87
# BaggingRegressor                        0.21      980.03    423.70
# KNeighborsRegressor                     0.48     1406.88    628.54
# GradientBoostingRegressor               0.32     1001.55    353.47
# XGBRegressor                            0.38      900.22    291.36
# AdaBoostRegressor                       0.25      979.58    380.53
# PassiveAggressiveRegressor              0.55     1265.58    702.98
# DecisionTreeRegressor                   0.87     1188.12    478.68
# SVR                                     0.11     1767.56    694.69
# QuantileRegressor                       0.11     1768.89    694.95
# HuberRegressor                          0.93     1400.99    819.46
# ExtraTreeRegressor                      0.70     1320.95    571.88
# GaussianProcessRegressor                0.34     2089.52    748.50
# GammaRegressor                         29.35     2728.44   4294.23
# RANSACRegressor                         1.54     1780.60    915.68
# NuSVR                                   0.24     1733.63    669.66
# ElasticNet                              0.67     1369.59    576.42
# RidgeCV                                 1.09     1534.84    672.97
# TweedieRegressor                        0.46     1296.88    540.18
# BayesianRidge                           1.56     1679.38    825.49
# KernelRidge                             2.22     1911.58    878.12
# ElasticNetCV                            0.40     1273.59    540.01
# LassoLarsIC                             2.36     1898.49    876.42
# SGDRegressor                            1.90     1858.43    879.35
# Ridge                                   2.23     1918.28    875.19
# Lasso                                   2.87     2068.11    990.23
# LassoLars                               2.87     2068.31    990.27
# TransformedTargetRegressor              2.90     2077.00    998.80
# LinearRegression                        2.90     2077.00    998.80
# OrthogonalMatchingPursuitCV             2.92     2094.60    958.98
# OrthogonalMatchingPursuit               4.96     2267.58    983.49
# LassoLarsCV                             1.84     1825.67    723.01
# LassoCV                                 1.86     1817.71    719.03
# LarsCV                                  1.84     1826.47    723.41
# Lars                                   45.35     2505.47   2824.10
# HistGradientBoostingRegressor           0.79     1392.39    416.26
# LGBMRegressor                           0.88     1397.88    435.32
# LinearSVR                               0.76     2302.94    664.29
# DummyRegressor                          0.62     1729.36    566.85
# MLPRegressor                            0.89     2356.26    656.03
# PoissonRegressor                     4815.96    19219.96  52381.43
#
#                                Time Taken_media  Time Taken_std  \
# ExtraTreesRegressor                        0.04            0.00
# RandomForestRegressor                      0.06            0.00
# BaggingRegressor                           0.01            0.00
# KNeighborsRegressor                        0.01            0.00
# GradientBoostingRegressor                  0.04            0.01
# XGBRegressor                               0.17            0.03
# AdaBoostRegressor                          0.07            0.01
# PassiveAggressiveRegressor                 0.01            0.00
# DecisionTreeRegressor                      0.01            0.00
# SVR                                        0.01            0.00
# QuantileRegressor                          0.03            0.01
# HuberRegressor                             0.02            0.00
# ExtraTreeRegressor                         0.01            0.00
# GaussianProcessRegressor                   0.01            0.00
# GammaRegressor                             0.01            0.00
# RANSACRegressor                            0.05            0.01
# NuSVR                                      0.01            0.00
# ElasticNet                                 0.01            0.00
# RidgeCV                                    0.01            0.00
# TweedieRegressor                           0.01            0.00
# BayesianRidge                              0.01            0.00
# KernelRidge                                0.01            0.00
# ElasticNetCV                               0.03            0.00
# LassoLarsIC                                0.01            0.00
# SGDRegressor                               0.01            0.00
# Ridge                                      0.01            0.00
# Lasso                                      0.01            0.00
# LassoLars                                  0.01            0.00
# TransformedTargetRegressor                 0.01            0.00
# LinearRegression                           0.01            0.00
# OrthogonalMatchingPursuitCV                0.01            0.00
# OrthogonalMatchingPursuit                  0.01            0.00
# LassoLarsCV                                0.01            0.00
# LassoCV                                    0.03            0.01
# LarsCV                                     0.01            0.00
# Lars                                       0.01            0.00
# HistGradientBoostingRegressor              0.10            0.04
# LGBMRegressor                              0.07            0.01
# LinearSVR                                  0.01            0.00
# DummyRegressor                             0.01            0.00
# MLPRegressor                               0.04            0.01
# PoissonRegressor                           0.01            0.00
#
#                                mean_absolute_percentage_error_media  \
# ExtraTreesRegressor                                            0.35
# RandomForestRegressor                                          0.36
# BaggingRegressor                                               0.37
# KNeighborsRegressor                                            0.38
# GradientBoostingRegressor                                      0.38
# XGBRegressor                                                   0.38
# AdaBoostRegressor                                              0.38
# PassiveAggressiveRegressor                                     0.42
# DecisionTreeRegressor                                          0.43
# SVR                                                            0.44
# QuantileRegressor                                              0.44
# HuberRegressor                                                 0.45
# ExtraTreeRegressor                                             0.46
# GaussianProcessRegressor                                       0.52
# GammaRegressor                                                 0.52
# RANSACRegressor                                                0.53
# NuSVR                                                          0.55
# ElasticNet                                                     0.58
# RidgeCV                                                        0.59
# TweedieRegressor                                               0.61
# BayesianRidge                                                  0.61
# KernelRidge                                                    0.63
# ElasticNetCV                                                   0.63
# LassoLarsIC                                                    0.64
# SGDRegressor                                                   0.65
# Ridge                                                          0.65
# Lasso                                                          0.67
# LassoLars                                                      0.67
# TransformedTargetRegressor                                     0.67
# LinearRegression                                               0.67
# OrthogonalMatchingPursuitCV                                    0.67
# OrthogonalMatchingPursuit                                      0.70
# LassoLarsCV                                                    0.72
# LassoCV                                                        0.72
# LarsCV                                                         0.72
# Lars                                                           0.75
# HistGradientBoostingRegressor                                  0.78
# LGBMRegressor                                                  0.78
# LinearSVR                                                      0.90
# DummyRegressor                                                 0.97
# MLPRegressor                                                   0.99
# PoissonRegressor                                               1.26
#
#                                mean_absolute_percentage_error_std
# ExtraTreesRegressor                                          0.06
# RandomForestRegressor                                        0.06
# BaggingRegressor                                             0.06
# KNeighborsRegressor                                          0.05
# GradientBoostingRegressor                                    0.06
# XGBRegressor                                                 0.07
# AdaBoostRegressor                                            0.05
# PassiveAggressiveRegressor                                   0.09
# DecisionTreeRegressor                                        0.09
# SVR                                                          0.05
# QuantileRegressor                                            0.05
# HuberRegressor                                               0.10
# ExtraTreeRegressor                                           0.10
# GaussianProcessRegressor                                     0.06
# GammaRegressor                                               0.15
# RANSACRegressor                                              0.21
# NuSVR                                                        0.10
# ElasticNet                                                   0.15
# RidgeCV                                                      0.15
# TweedieRegressor                                             0.15
# BayesianRidge                                                0.16
# KernelRidge                                                  0.17
# ElasticNetCV                                                 0.15
# LassoLarsIC                                                  0.16
# SGDRegressor                                                 0.18
# Ridge                                                        0.18
# Lasso                                                        0.19
# LassoLars                                                    0.19
# TransformedTargetRegressor                                   0.19
# LinearRegression                                             0.19
# OrthogonalMatchingPursuitCV                                  0.19
# OrthogonalMatchingPursuit                                    0.16
# LassoLarsCV                                                  0.21
# LassoCV                                                      0.21
# LarsCV                                                       0.21
# Lars                                                         0.51
# HistGradientBoostingRegressor                                0.19
# LGBMRegressor                                                0.20
# LinearSVR                                                    0.01
# DummyRegressor                                               0.19
# MLPRegressor                                                 0.00
# PoissonRegressor                                             1.81

# %% [markdown]
# # Sala

# %%
results_dict = train(property_dfs,"Sala")

results_dict_format = {}

#imprime
for model in results_dict:
    results_dict_format[model]={}
    for metric in results_dict[model]:
        mean = np.mean(results_dict[model][metric]["mean"])
        std = np.std(results_dict[model][metric]["mean"])
        results_dict_format[model][metric + "_media"] = mean
        results_dict_format[model][metric + "_std"] = std

df = pd.DataFrame(results_dict_format)
df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
# Out:
# 100%|██████████| 42/42 [00:01<00:00, 39.33it/s]
# 100%|██████████| 42/42 [00:00<00:00, 46.21it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.77it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.45it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.25it/s]
# 100%|██████████| 42/42 [00:01<00:00, 40.66it/s]
# 100%|██████████| 42/42 [00:00<00:00, 42.78it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.64it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.12it/s]
# 100%|██████████| 42/42 [00:01<00:00, 38.70it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.45it/s]
# 100%|██████████| 42/42 [00:01<00:00, 37.64it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.89it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.38it/s]
# 100%|██████████| 42/42 [00:01<00:00, 37.22it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.37it/s]
# 100%|██████████| 42/42 [00:01<00:00, 37.35it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.12it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.41it/s]
# 100%|██████████| 42/42 [00:00<00:00, 44.30it/s]
# 100%|██████████| 42/42 [00:01<00:00, 38.98it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.92it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.74it/s]
# 100%|██████████| 42/42 [00:01<00:00, 36.61it/s]
# 100%|██████████| 42/42 [00:00<00:00, 46.94it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.82it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.44it/s]
# 100%|██████████| 42/42 [00:01<00:00, 40.23it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.21it/s]
# 100%|██████████| 42/42 [00:01<00:00, 41.90it/s]
# 100%|██████████| 42/42 [00:00<00:00, 48.00it/s]
# 100%|██████████| 42/42 [00:01<00:00, 38.95it/s]
# 100%|██████████| 42/42 [00:01<00:00, 40.69it/s]
#                                Adjusted R-Squared_media  \
# ExtraTreesRegressor                                0.19
# KNeighborsRegressor                               -0.01
# GradientBoostingRegressor                         -0.32
# RandomForestRegressor                              0.17
# BaggingRegressor                                   0.15
# XGBRegressor                                       0.00
# SVR                                               -1.01
# QuantileRegressor                                 -1.01
# DecisionTreeRegressor                             -0.67
# ExtraTreeRegressor                                -1.03
# PassiveAggressiveRegressor                        -0.11
# AdaBoostRegressor                                 -0.05
# HuberRegressor                                    -0.23
# RANSACRegressor                                   -1.18
# GammaRegressor                                    -8.79
# KernelRidge                                       -0.43
# LassoLarsIC                                       -0.49
# OrthogonalMatchingPursuitCV                       -0.52
# BayesianRidge                                     -0.48
# Ridge                                             -0.44
# RidgeCV                                           -0.37
# SGDRegressor                                      -0.55
# Lasso                                             -0.57
# LassoLars                                         -0.57
# TransformedTargetRegressor                        -0.57
# LinearRegression                                  -0.57
# Lars                                              -0.59
# ElasticNet                                         0.05
# LassoLarsCV                                       -0.30
# LassoCV                                           -0.29
# OrthogonalMatchingPursuit                         -0.02
# GaussianProcessRegressor                          -1.44
# LarsCV                                            -0.36
# NuSVR                                             -0.87
# TweedieRegressor                                   0.06
# LinearSVR                                         -1.59
# MLPRegressor                                      -1.65
# ElasticNetCV                                      -0.17
# LGBMRegressor                                     -0.58
# HistGradientBoostingRegressor                     -0.63
# DummyRegressor                                    -0.92
# PoissonRegressor                              -50756.38
#
#                                Adjusted R-Squared_std  R-Squared_media  \
# ExtraTreesRegressor                              0.75             0.52
# KNeighborsRegressor                              0.38             0.40
# GradientBoostingRegressor                        2.01             0.22
# RandomForestRegressor                            0.67             0.51
# BaggingRegressor                                 0.69             0.50
# XGBRegressor                                     0.83             0.41
# SVR                                              0.15            -0.18
# QuantileRegressor                                0.15            -0.19
# DecisionTreeRegressor                            3.24             0.01
# ExtraTreeRegressor                               3.22            -0.20
# PassiveAggressiveRegressor                       0.65             0.34
# AdaBoostRegressor                                0.59             0.38
# HuberRegressor                                   0.87             0.27
# RANSACRegressor                                  2.84            -0.29
# GammaRegressor                                  21.86            -4.79
# KernelRidge                                      1.43             0.15
# LassoLarsIC                                      1.46             0.12
# OrthogonalMatchingPursuitCV                      1.69             0.10
# BayesianRidge                                    1.50             0.13
# Ridge                                            1.46             0.15
# RidgeCV                                          1.16             0.19
# SGDRegressor                                     1.61             0.08
# Lasso                                            1.63             0.07
# LassoLars                                        1.63             0.07
# TransformedTargetRegressor                       1.64             0.07
# LinearRegression                                 1.64             0.07
# Lars                                             1.65             0.06
# ElasticNet                                       0.65             0.44
# LassoLarsCV                                      1.56             0.23
# LassoCV                                          1.56             0.24
# OrthogonalMatchingPursuit                        0.77             0.40
# GaussianProcessRegressor                         0.41            -0.44
# LarsCV                                           1.60             0.20
# NuSVR                                            0.14            -0.11
# TweedieRegressor                                 0.52             0.44
# LinearSVR                                        0.37            -0.53
# MLPRegressor                                     0.41            -0.57
# ElasticNetCV                                     0.43             0.31
# LGBMRegressor                                    1.35             0.07
# HistGradientBoostingRegressor                    1.51             0.04
# DummyRegressor                                   0.51            -0.13
# PoissonRegressor                            200869.27        -29992.00
#
#                                R-Squared_std  RMSE_media  RMSE_std  \
# ExtraTreesRegressor                     0.45     2575.85   1090.00
# KNeighborsRegressor                     0.22     3157.42   1527.32
# GradientBoostingRegressor               1.18     2993.19   1015.45
# RandomForestRegressor                   0.40     2679.44   1167.31
# BaggingRegressor                        0.41     2691.35   1241.18
# XGBRegressor                            0.49     2847.73   1050.39
# SVR                                     0.09     4376.95   1578.85
# QuantileRegressor                       0.09     4378.47   1578.99
# DecisionTreeRegressor                   1.91     3078.09   1255.50
# ExtraTreeRegressor                      1.91     3360.41   1146.65
# PassiveAggressiveRegressor              0.38     3123.14   1172.43
# AdaBoostRegressor                       0.35     2972.06   1068.58
# HuberRegressor                          0.51     3174.69   1177.42
# RANSACRegressor                         1.68     3805.15   1553.85
# GammaRegressor                         12.92     6912.38   9103.80
# KernelRidge                             0.85     3232.47   1026.32
# LassoLarsIC                             0.86     3260.51   1049.32
# OrthogonalMatchingPursuitCV             1.00     3183.13   1105.92
# BayesianRidge                           0.89     3259.02   1046.84
# Ridge                                   0.86     3231.58   1025.58
# RidgeCV                                 0.69     3251.21   1169.81
# SGDRegressor                            0.95     3300.86   1037.12
# Lasso                                   0.97     3304.66   1043.41
# LassoLars                               0.97     3304.94   1043.63
# TransformedTargetRegressor              0.97     3307.44   1044.97
# LinearRegression                        0.97     3307.44   1044.97
# Lars                                    0.98     3321.13   1065.69
# ElasticNet                              0.39     2930.18   1282.11
# LassoLarsCV                             0.92     3049.61   1103.30
# LassoCV                                 0.92     3045.18   1105.89
# OrthogonalMatchingPursuit               0.46     2962.42   1269.89
# GaussianProcessRegressor                0.24     4786.82   1697.42
# LarsCV                                  0.95     3110.09   1106.28
# NuSVR                                   0.08     4241.08   1561.63
# TweedieRegressor                        0.31     2955.51   1412.18
# LinearSVR                               0.22     4856.62   1543.76
# MLPRegressor                            0.24     4896.64   1535.42
# ElasticNetCV                            0.25     3299.66   1397.04
# LGBMRegressor                           0.80     3513.87   1092.30
# HistGradientBoostingRegressor           0.89     3522.95   1063.61
# DummyRegressor                          0.30     4165.70   1394.65
# PoissonRegressor                   118695.48   272555.52 973969.25
#
#                                Time Taken_media  Time Taken_std  \
# ExtraTreesRegressor                        0.04            0.01
# KNeighborsRegressor                        0.01            0.01
# GradientBoostingRegressor                  0.03            0.01
# RandomForestRegressor                      0.06            0.01
# BaggingRegressor                           0.02            0.01
# XGBRegressor                               0.18            0.04
# SVR                                        0.01            0.00
# QuantileRegressor                          0.03            0.01
# DecisionTreeRegressor                      0.01            0.01
# ExtraTreeRegressor                         0.01            0.00
# PassiveAggressiveRegressor                 0.01            0.00
# AdaBoostRegressor                          0.06            0.02
# HuberRegressor                             0.02            0.01
# RANSACRegressor                            0.05            0.01
# GammaRegressor                             0.01            0.00
# KernelRidge                                0.01            0.01
# LassoLarsIC                                0.01            0.00
# OrthogonalMatchingPursuitCV                0.01            0.00
# BayesianRidge                              0.01            0.00
# Ridge                                      0.01            0.00
# RidgeCV                                    0.01            0.00
# SGDRegressor                               0.01            0.00
# Lasso                                      0.01            0.00
# LassoLars                                  0.01            0.00
# TransformedTargetRegressor                 0.01            0.00
# LinearRegression                           0.01            0.00
# Lars                                       0.01            0.00
# ElasticNet                                 0.01            0.00
# LassoLarsCV                                0.01            0.00
# LassoCV                                    0.03            0.00
# OrthogonalMatchingPursuit                  0.01            0.00
# GaussianProcessRegressor                   0.01            0.00
# LarsCV                                     0.01            0.00
# NuSVR                                      0.01            0.00
# TweedieRegressor                           0.01            0.00
# LinearSVR                                  0.01            0.00
# MLPRegressor                               0.04            0.01
# ElasticNetCV                               0.03            0.00
# LGBMRegressor                              0.07            0.01
# HistGradientBoostingRegressor              0.11            0.03
# DummyRegressor                             0.01            0.00
# PoissonRegressor                           0.01            0.00
#
#                                mean_absolute_percentage_error_media  \
# ExtraTreesRegressor                                            0.48
# KNeighborsRegressor                                            0.54
# GradientBoostingRegressor                                      0.54
# RandomForestRegressor                                          0.55
# BaggingRegressor                                               0.56
# XGBRegressor                                                   0.56
# SVR                                                            0.59
# QuantileRegressor                                              0.59
# DecisionTreeRegressor                                          0.62
# ExtraTreeRegressor                                             0.63
# PassiveAggressiveRegressor                                     0.63
# AdaBoostRegressor                                              0.65
# HuberRegressor                                                 0.66
# RANSACRegressor                                                0.67
# GammaRegressor                                                 0.74
# KernelRidge                                                    0.74
# LassoLarsIC                                                    0.75
# OrthogonalMatchingPursuitCV                                    0.75
# BayesianRidge                                                  0.76
# Ridge                                                          0.76
# RidgeCV                                                        0.76
# SGDRegressor                                                   0.77
# Lasso                                                          0.78
# LassoLars                                                      0.78
# TransformedTargetRegressor                                     0.78
# LinearRegression                                               0.78
# Lars                                                           0.78
# ElasticNet                                                     0.80
# LassoLarsCV                                                    0.80
# LassoCV                                                        0.80
# OrthogonalMatchingPursuit                                      0.80
# GaussianProcessRegressor                                       0.86
# LarsCV                                                         0.86
# NuSVR                                                          0.86
# TweedieRegressor                                               0.91
# LinearSVR                                                      0.91
# MLPRegressor                                                   0.99
# ElasticNetCV                                                   1.18
# LGBMRegressor                                                  1.33
# HistGradientBoostingRegressor                                  1.34
# DummyRegressor                                                 1.63
# PoissonRegressor                                               4.44
#
#                                mean_absolute_percentage_error_std
# ExtraTreesRegressor                                          0.13
# KNeighborsRegressor                                          0.12
# GradientBoostingRegressor                                    0.21
# RandomForestRegressor                                        0.18
# BaggingRegressor                                             0.19
# XGBRegressor                                                 0.21
# SVR                                                          0.11
# QuantileRegressor                                            0.11
# DecisionTreeRegressor                                        0.24
# ExtraTreeRegressor                                           0.23
# PassiveAggressiveRegressor                                   0.14
# AdaBoostRegressor                                            0.24
# HuberRegressor                                               0.17
# RANSACRegressor                                              0.19
# GammaRegressor                                               0.16
# KernelRidge                                                  0.20
# LassoLarsIC                                                  0.21
# OrthogonalMatchingPursuitCV                                  0.22
# BayesianRidge                                                0.21
# Ridge                                                        0.21
# RidgeCV                                                      0.21
# SGDRegressor                                                 0.22
# Lasso                                                        0.22
# LassoLars                                                    0.22
# TransformedTargetRegressor                                   0.22
# LinearRegression                                             0.22
# Lars                                                         0.22
# ElasticNet                                                   0.22
# LassoLarsCV                                                  0.24
# LassoCV                                                      0.24
# OrthogonalMatchingPursuit                                    0.18
# GaussianProcessRegressor                                     0.36
# LarsCV                                                       0.28
# NuSVR                                                        0.21
# TweedieRegressor                                             0.25
# LinearSVR                                                    0.01
# MLPRegressor                                                 0.00
# ElasticNetCV                                                 0.34
# LGBMRegressor                                                0.36
# HistGradientBoostingRegressor                                0.40
# DummyRegressor                                               0.43
# PoissonRegressor                                            13.58

# %% [markdown]
# # Cobertura

# %%
results_dict = train(property_dfs,"Cobertura")

results_dict_format = {}

#imprime
for model in results_dict:
    results_dict_format[model]={}
    for metric in results_dict[model]:
        mean = np.mean(results_dict[model][metric]["mean"])
        std = np.std(results_dict[model][metric]["mean"])
        results_dict_format[model][metric + "_media"] = mean
        results_dict_format[model][metric + "_std"] = std

df = pd.DataFrame(results_dict_format)
df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# 100%|██████████| 42/42 [00:00<00:00, 49.27it/s]
# 100%|██████████| 42/42 [00:00<00:00, 49.00it/s]
# 100%|██████████| 42/42 [00:00<00:00, 61.74it/s]
# 100%|██████████| 42/42 [00:00<00:00, 63.28it/s]
# 100%|██████████| 42/42 [00:00<00:00, 59.02it/s]
# 100%|██████████| 42/42 [00:00<00:00, 74.81it/s]
# 100%|██████████| 42/42 [00:00<00:00, 71.13it/s]
# 100%|██████████| 42/42 [00:00<00:00, 52.61it/s]
# 100%|██████████| 42/42 [00:00<00:00, 61.71it/s]
# 100%|██████████| 42/42 [00:00<00:00, 55.44it/s]
# 100%|██████████| 42/42 [00:00<00:00, 60.76it/s]
# 100%|██████████| 42/42 [00:00<00:00, 58.10it/s]
# 100%|██████████| 42/42 [00:00<00:00, 51.74it/s]
# 100%|██████████| 42/42 [00:00<00:00, 58.27it/s]
# 100%|██████████| 42/42 [00:00<00:00, 50.36it/s]
# 100%|██████████| 42/42 [00:00<00:00, 47.10it/s]
# 100%|██████████| 42/42 [00:00<00:00, 60.30it/s]
# 100%|██████████| 42/42 [00:00<00:00, 59.33it/s]
# 100%|██████████| 42/42 [00:00<00:00, 55.88it/s]
# 100%|██████████| 42/42 [00:00<00:00, 60.21it/s]
# 100%|██████████| 42/42 [00:00<00:00, 55.68it/s]
# 100%|██████████| 42/42 [00:00<00:00, 71.78it/s]
# 100%|██████████| 42/42 [00:00<00:00, 62.68it/s]
# 100%|██████████| 42/42 [00:00<00:00, 59.78it/s]
# 100%|██████████| 42/42 [00:00<00:00, 63.89it/s]
# 100%|██████████| 42/42 [00:00<00:00, 65.86it/s]
# 100%|██████████| 42/42 [00:00<00:00, 58.83it/s]
# 100%|██████████| 42/42 [00:00<00:00, 55.77it/s]
# 100%|██████████| 42/42 [00:00<00:00, 54.29it/s]
# 100%|██████████| 42/42 [00:00<00:00, 56.44it/s]
# 100%|██████████| 42/42 [00:00<00:00, 57.27it/s]
# 100%|██████████| 42/42 [00:00<00:00, 55.67it/s]
# 100%|██████████| 42/42 [00:00<00:00, 56.56it/s]
#                                         Adjusted R-Squared_media  \
# ExtraTreesRegressor                                         2.13
# SVR                                                         2.04
# QuantileRegressor                                           2.07
# AdaBoostRegressor                                           2.47
# ExtraTreeRegressor                                          2.63
# KNeighborsRegressor                                         3.85
# NuSVR                                                       2.97
# RandomForestRegressor                                       5.25
# GammaRegressor                                              2.98
# XGBRegressor                                                6.27
# BaggingRegressor                                            5.60
# GradientBoostingRegressor                                  13.25
# GaussianProcessRegressor                                    4.39
# DummyRegressor                                              5.21
# LGBMRegressor                                               5.21
# HistGradientBoostingRegressor                               5.21
# ElasticNetCV                                                8.33
# TweedieRegressor                                            9.56
# OrthogonalMatchingPursuit                                  12.23
# ElasticNet                                                 10.96
# LassoLarsCV                                                 9.42
# MLPRegressor                                                5.88
# LassoCV                                                     9.47
# LinearSVR                                                   5.90
# OrthogonalMatchingPursuitCV                                17.11
# RidgeCV                                                    16.29
# KernelRidge                                                14.91
# DecisionTreeRegressor                                      29.00
# Ridge                                                      14.45
# SGDRegressor                                               18.05
# BayesianRidge                                              21.19
# PassiveAggressiveRegressor                                 21.44
# LarsCV                                                      8.87
# HuberRegressor                                             28.51
# Lasso                                                      63.95
# LassoLars                                                  68.16
# TransformedTargetRegressor                                195.28
# LinearRegression                                          195.28
# PoissonRegressor                             4110344692271196.00
# Lars                          5719608245209575339203470819328.00
#
#                                            Adjusted R-Squared_std  \
# ExtraTreesRegressor                                          1.48
# SVR                                                          1.24
# QuantileRegressor                                            1.26
# AdaBoostRegressor                                            2.02
# ExtraTreeRegressor                                           2.08
# KNeighborsRegressor                                          6.68
# NuSVR                                                        2.81
# RandomForestRegressor                                       11.15
# GammaRegressor                                               2.48
# XGBRegressor                                                11.53
# BaggingRegressor                                            12.65
# GradientBoostingRegressor                                   45.93
# GaussianProcessRegressor                                     3.72
# DummyRegressor                                               6.52
# LGBMRegressor                                                6.52
# HistGradientBoostingRegressor                                6.52
# ElasticNetCV                                                12.22
# TweedieRegressor                                            15.27
# OrthogonalMatchingPursuit                                   19.43
# ElasticNet                                                  18.91
# LassoLarsCV                                                 14.14
# MLPRegressor                                                 5.46
# LassoCV                                                     14.04
# LinearSVR                                                    5.44
# OrthogonalMatchingPursuitCV                                 26.75
# RidgeCV                                                     33.44
# KernelRidge                                                 25.70
# DecisionTreeRegressor                                       97.43
# Ridge                                                       24.83
# SGDRegressor                                                29.55
# BayesianRidge                                               37.89
# PassiveAggressiveRegressor                                  34.71
# LarsCV                                                      13.58
# HuberRegressor                                              43.64
# Lasso                                                      119.50
# LassoLars                                                  122.46
# TransformedTargetRegressor                                 654.87
# LinearRegression                                           654.87
# PoissonRegressor                             23251620838936820.00
# Lars                          32322499372543672013070765391872.00
#
#                                                    R-Squared_media  \
# ExtraTreesRegressor                                          -1.25
# SVR                                                          -1.08
# QuantileRegressor                                            -1.14
# AdaBoostRegressor                                            -1.95
# ExtraTreeRegressor                                           -2.26
# KNeighborsRegressor                                          -4.70
# NuSVR                                                        -2.93
# RandomForestRegressor                                        -7.49
# GammaRegressor                                               -2.96
# XGBRegressor                                                 -9.54
# BaggingRegressor                                             -8.21
# GradientBoostingRegressor                                   -23.51
# GaussianProcessRegressor                                     -5.79
# DummyRegressor                                               -7.42
# LGBMRegressor                                                -7.42
# HistGradientBoostingRegressor                                -7.42
# ElasticNetCV                                                -13.66
# TweedieRegressor                                            -16.11
# OrthogonalMatchingPursuit                                   -21.47
# ElasticNet                                                  -18.93
# LassoLarsCV                                                 -15.84
# MLPRegressor                                                 -8.75
# LassoCV                                                     -15.93
# LinearSVR                                                    -8.81
# OrthogonalMatchingPursuitCV                                 -31.21
# RidgeCV                                                     -29.58
# KernelRidge                                                 -26.82
# DecisionTreeRegressor                                       -54.99
# Ridge                                                       -25.90
# SGDRegressor                                                -33.11
# BayesianRidge                                               -39.38
# PassiveAggressiveRegressor                                  -39.87
# LarsCV                                                      -14.75
# HuberRegressor                                              -54.02
# Lasso                                                      -124.91
# LassoLars                                                  -133.32
# TransformedTargetRegressor                                 -387.56
# LinearRegression                                           -387.56
# PoissonRegressor                              -8220689384542389.00
# Lars                          -11439216490419150678406941638656.00
#
#                                                     R-Squared_std  \
# ExtraTreesRegressor                                          2.97
# SVR                                                          2.49
# QuantileRegressor                                            2.53
# AdaBoostRegressor                                            4.04
# ExtraTreeRegressor                                           4.17
# KNeighborsRegressor                                         13.35
# NuSVR                                                        5.62
# RandomForestRegressor                                       22.30
# GammaRegressor                                               4.95
# XGBRegressor                                                23.07
# BaggingRegressor                                            25.30
# GradientBoostingRegressor                                   91.85
# GaussianProcessRegressor                                     7.44
# DummyRegressor                                              13.03
# LGBMRegressor                                               13.03
# HistGradientBoostingRegressor                               13.03
# ElasticNetCV                                                24.43
# TweedieRegressor                                            30.54
# OrthogonalMatchingPursuit                                   38.85
# ElasticNet                                                  37.81
# LassoLarsCV                                                 28.28
# MLPRegressor                                                10.92
# LassoCV                                                     28.08
# LinearSVR                                                   10.89
# OrthogonalMatchingPursuitCV                                 53.50
# RidgeCV                                                     66.87
# KernelRidge                                                 51.39
# DecisionTreeRegressor                                      194.86
# Ridge                                                       49.65
# SGDRegressor                                                59.10
# BayesianRidge                                               75.78
# PassiveAggressiveRegressor                                  69.43
# LarsCV                                                      27.17
# HuberRegressor                                              87.27
# Lasso                                                      239.00
# LassoLars                                                  244.93
# TransformedTargetRegressor                                1309.75
# LinearRegression                                          1309.75
# PoissonRegressor                             46503241677873640.00
# Lars                          64644998745087344026141530783744.00
#
#                                           RMSE_media               RMSE_std  \
# ExtraTreesRegressor                          1258.70                1040.66
# SVR                                          1418.23                1098.02
# QuantileRegressor                            1420.95                1091.10
# AdaBoostRegressor                            1457.66                1077.36
# ExtraTreeRegressor                           1525.73                1109.20
# KNeighborsRegressor                          1483.34                1112.98
# NuSVR                                        1511.23                 984.00
# RandomForestRegressor                        1500.07                1007.55
# GammaRegressor                               1766.48                1600.65
# XGBRegressor                                 1854.57                1100.04
# BaggingRegressor                             1526.52                 972.39
# GradientBoostingRegressor                    1656.07                1013.76
# GaussianProcessRegressor                     2056.49                1199.10
# DummyRegressor                               1638.89                 857.85
# LGBMRegressor                                1638.89                 857.85
# HistGradientBoostingRegressor                1638.89                 857.85
# ElasticNetCV                                 2036.86                1119.25
# TweedieRegressor                             2142.48                1214.19
# OrthogonalMatchingPursuit                    2316.66                 894.02
# ElasticNet                                   2257.64                1371.68
# LassoLarsCV                                  2192.20                1256.27
# MLPRegressor                                 2185.66                1099.27
# LassoCV                                      2211.63                1288.00
# LinearSVR                                    2193.97                1099.72
# OrthogonalMatchingPursuitCV                  2632.45                1248.84
# RidgeCV                                      2440.78                1660.56
# KernelRidge                                  2689.05                1667.79
# DecisionTreeRegressor                        2430.32                1120.18
# Ridge                                        2633.30                1623.20
# SGDRegressor                                 2975.34                1948.85
# BayesianRidge                                3134.65                2200.51
# PassiveAggressiveRegressor                   3277.60                1955.19
# LarsCV                                       2864.88                5052.70
# HuberRegressor                               3913.53                2816.74
# Lasso                                        4612.42                3319.85
# LassoLars                                    4695.66                3337.85
# TransformedTargetRegressor                   6508.51                4660.50
# LinearRegression                             6508.51                4660.50
# PoissonRegressor                      13531575149.20         76544778870.27
# Lars                          1507375194795368960.00 8286282160331646976.00
#
#                                Time Taken_media  Time Taken_std  \
# ExtraTreesRegressor                        0.04            0.00
# SVR                                        0.01            0.00
# QuantileRegressor                          0.01            0.00
# AdaBoostRegressor                          0.06            0.02
# ExtraTreeRegressor                         0.01            0.00
# KNeighborsRegressor                        0.01            0.00
# NuSVR                                      0.01            0.00
# RandomForestRegressor                      0.06            0.01
# GammaRegressor                             0.01            0.00
# XGBRegressor                               0.08            0.03
# BaggingRegressor                           0.01            0.00
# GradientBoostingRegressor                  0.03            0.01
# GaussianProcessRegressor                   0.01            0.00
# DummyRegressor                             0.01            0.00
# LGBMRegressor                              0.02            0.01
# HistGradientBoostingRegressor              0.05            0.02
# ElasticNetCV                               0.01            0.00
# TweedieRegressor                           0.01            0.00
# OrthogonalMatchingPursuit                  0.01            0.00
# ElasticNet                                 0.01            0.00
# LassoLarsCV                                0.01            0.00
# MLPRegressor                               0.03            0.00
# LassoCV                                    0.02            0.00
# LinearSVR                                  0.01            0.00
# OrthogonalMatchingPursuitCV                0.01            0.00
# RidgeCV                                    0.01            0.00
# KernelRidge                                0.01            0.00
# DecisionTreeRegressor                      0.01            0.00
# Ridge                                      0.01            0.00
# SGDRegressor                               0.01            0.00
# BayesianRidge                              0.01            0.00
# PassiveAggressiveRegressor                 0.01            0.00
# LarsCV                                     0.01            0.01
# HuberRegressor                             0.03            0.01
# Lasso                                      0.01            0.00
# LassoLars                                  0.01            0.00
# TransformedTargetRegressor                 0.01            0.00
# LinearRegression                           0.01            0.00
# PoissonRegressor                           0.02            0.00
# Lars                                       0.01            0.01
#
#                                mean_absolute_percentage_error_media  \
# ExtraTreesRegressor                                            0.42
# SVR                                                            0.44
# QuantileRegressor                                              0.45
# AdaBoostRegressor                                              0.46
# ExtraTreeRegressor                                             0.47
# KNeighborsRegressor                                            0.55
# NuSVR                                                          0.57
# RandomForestRegressor                                          0.63
# GammaRegressor                                                 0.64
# XGBRegressor                                                   0.64
# BaggingRegressor                                               0.68
# GradientBoostingRegressor                                      0.69
# GaussianProcessRegressor                                       0.72
# DummyRegressor                                                 0.81
# LGBMRegressor                                                  0.81
# HistGradientBoostingRegressor                                  0.81
# ElasticNetCV                                                   0.89
# TweedieRegressor                                               0.89
# OrthogonalMatchingPursuit                                      0.91
# ElasticNet                                                     0.91
# LassoLarsCV                                                    0.98
# MLPRegressor                                                   0.98
# LassoCV                                                        0.98
# LinearSVR                                                      0.99
# OrthogonalMatchingPursuitCV                                    1.00
# RidgeCV                                                        1.00
# KernelRidge                                                    1.02
# DecisionTreeRegressor                                          1.03
# Ridge                                                          1.05
# SGDRegressor                                                   1.20
# BayesianRidge                                                  1.27
# PassiveAggressiveRegressor                                     1.34
# LarsCV                                                         1.34
# HuberRegressor                                                 1.61
# Lasso                                                          2.07
# LassoLars                                                      2.11
# TransformedTargetRegressor                                     3.08
# LinearRegression                                               3.08
# PoissonRegressor                                         3758770.07
# Lars                                             685234572007566.38
#
#                                mean_absolute_percentage_error_std
# ExtraTreesRegressor                                          0.15
# SVR                                                          0.17
# QuantileRegressor                                            0.17
# AdaBoostRegressor                                            0.19
# ExtraTreeRegressor                                           0.16
# KNeighborsRegressor                                          0.40
# NuSVR                                                        0.25
# RandomForestRegressor                                        0.42
# GammaRegressor                                               0.43
# XGBRegressor                                                 0.29
# BaggingRegressor                                             0.51
# GradientBoostingRegressor                                    0.81
# GaussianProcessRegressor                                     0.17
# DummyRegressor                                               0.40
# LGBMRegressor                                                0.40
# HistGradientBoostingRegressor                                0.40
# ElasticNetCV                                                 0.51
# TweedieRegressor                                             0.54
# OrthogonalMatchingPursuit                                    0.43
# ElasticNet                                                   0.58
# LassoLarsCV                                                  0.55
# MLPRegressor                                                 0.01
# LassoCV                                                      0.56
# LinearSVR                                                    0.00
# OrthogonalMatchingPursuitCV                                  0.58
# RidgeCV                                                      0.68
# KernelRidge                                                  0.64
# DecisionTreeRegressor                                        1.18
# Ridge                                                        0.65
# SGDRegressor                                                 0.76
# BayesianRidge                                                0.94
# PassiveAggressiveRegressor                                   0.76
# LarsCV                                                       2.45
# HuberRegressor                                               1.06
# Lasso                                                        1.62
# LassoLars                                                    1.62
# TransformedTargetRegressor                                   2.64
# LinearRegression                                             2.64
# PoissonRegressor                                      21262439.12
# Lars                                          3773820310100750.00

# %% [markdown]
# # Loja

# %%
results_dict = train(property_dfs,"Loja")

results_dict_format = {}

#imprime
for model in results_dict:
    results_dict_format[model]={}
    for metric in results_dict[model]:
        mean = np.mean(results_dict[model][metric]["mean"])
        std = np.std(results_dict[model][metric]["mean"])
        results_dict_format[model][metric + "_media"] = mean
        results_dict_format[model][metric + "_std"] = std

df = pd.DataFrame(results_dict_format)
df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
# Out:
# 100%|██████████| 42/42 [00:01<00:00, 24.10it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.68it/s]
# 100%|██████████| 42/42 [00:01<00:00, 32.27it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.95it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.65it/s]
# 100%|██████████| 42/42 [00:01<00:00, 24.37it/s]
# 100%|██████████| 42/42 [00:01<00:00, 29.68it/s]
# 100%|██████████| 42/42 [00:01<00:00, 33.56it/s]
# 100%|██████████| 42/42 [00:01<00:00, 28.09it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.46it/s]
# 100%|██████████| 42/42 [00:01<00:00, 26.07it/s]
# 100%|██████████| 42/42 [00:01<00:00, 29.18it/s]
# 100%|██████████| 42/42 [00:01<00:00, 27.17it/s]
# 100%|██████████| 42/42 [00:01<00:00, 26.46it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.03it/s]
# 100%|██████████| 42/42 [00:01<00:00, 24.45it/s]
# 100%|██████████| 42/42 [00:01<00:00, 27.03it/s]
# 100%|██████████| 42/42 [00:01<00:00, 23.56it/s]
# 100%|██████████| 42/42 [00:01<00:00, 28.56it/s]
# 100%|██████████| 42/42 [00:01<00:00, 31.67it/s]
# 100%|██████████| 42/42 [00:01<00:00, 39.52it/s]
# 100%|██████████| 42/42 [00:01<00:00, 28.89it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.01it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.65it/s]
# 100%|██████████| 42/42 [00:01<00:00, 24.35it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.08it/s]
# 100%|██████████| 42/42 [00:01<00:00, 30.17it/s]
# 100%|██████████| 42/42 [00:01<00:00, 24.52it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.09it/s]
# 100%|██████████| 42/42 [00:01<00:00, 31.86it/s]
# 100%|██████████| 42/42 [00:01<00:00, 27.65it/s]
# 100%|██████████| 42/42 [00:01<00:00, 26.72it/s]
# 100%|██████████| 42/42 [00:01<00:00, 23.76it/s]
#                                Adjusted R-Squared_media  \
# SVR                                               -0.35
# QuantileRegressor                                 -0.35
# RANSACRegressor                                   -0.06
# NuSVR                                             -0.32
# PassiveAggressiveRegressor                        -0.03
# ExtraTreesRegressor                                0.04
# HuberRegressor                                    -0.20
# RandomForestRegressor                              0.05
# XGBRegressor                                      -0.41
# GradientBoostingRegressor                         -0.20
# BaggingRegressor                                  -0.01
# ExtraTreeRegressor                                -0.62
# KNeighborsRegressor                               -0.05
# LinearSVR                                         -0.74
# DecisionTreeRegressor                             -0.64
# OrthogonalMatchingPursuit                          0.04
# LGBMRegressor                                      0.06
# HistGradientBoostingRegressor                      0.06
# GammaRegressor                                    -0.83
# OrthogonalMatchingPursuitCV                       -0.08
# ElasticNet                                         0.05
# TweedieRegressor                                   0.04
# RidgeCV                                           -0.03
# MLPRegressor                                      -0.89
# LassoLarsIC                                       -0.08
# BayesianRidge                                     -0.06
# AdaBoostRegressor                                 -0.05
# ElasticNetCV                                       0.02
# KernelRidge                                       -0.08
# LassoCV                                           -0.12
# LassoLarsCV                                       -0.13
# LarsCV                                            -0.13
# Ridge                                             -0.08
# LassoLars                                         -0.09
# Lasso                                             -0.09
# SGDRegressor                                      -0.09
# TransformedTargetRegressor                        -0.09
# LinearRegression                                  -0.09
# Lars                                              -0.09
# DummyRegressor                                    -0.29
# PoissonRegressor                                 -21.14
# GaussianProcessRegressor                          -5.94
#
#                                Adjusted R-Squared_std  R-Squared_media  \
# SVR                                              0.05            -0.11
# QuantileRegressor                                0.05            -0.11
# RANSACRegressor                                  0.29             0.13
# NuSVR                                            0.05            -0.08
# PassiveAggressiveRegressor                       0.41             0.15
# ExtraTreesRegressor                              0.59             0.21
# HuberRegressor                                   0.62             0.01
# RandomForestRegressor                            0.65             0.21
# XGBRegressor                                     1.36            -0.16
# GradientBoostingRegressor                        1.03             0.01
# BaggingRegressor                                 0.77             0.17
# ExtraTreeRegressor                               1.40            -0.33
# KNeighborsRegressor                              0.49             0.14
# LinearSVR                                        0.21            -0.43
# DecisionTreeRegressor                            1.70            -0.35
# OrthogonalMatchingPursuit                        0.53             0.21
# LGBMRegressor                                    0.50             0.22
# HistGradientBoostingRegressor                    0.54             0.22
# GammaRegressor                                   1.88            -0.51
# OrthogonalMatchingPursuitCV                      0.64             0.11
# ElasticNet                                       0.24             0.22
# TweedieRegressor                                 0.15             0.21
# RidgeCV                                          0.54             0.15
# MLPRegressor                                     0.32            -0.56
# LassoLarsIC                                      0.65             0.11
# BayesianRidge                                    0.59             0.13
# AdaBoostRegressor                                0.52             0.13
# ElasticNetCV                                     0.11             0.20
# KernelRidge                                      0.64             0.11
# LassoCV                                          0.50             0.08
# LassoLarsCV                                      0.51             0.07
# LarsCV                                           0.51             0.07
# Ridge                                            0.65             0.11
# LassoLars                                        0.67             0.10
# Lasso                                            0.67             0.10
# SGDRegressor                                     0.66             0.10
# TransformedTargetRegressor                       0.67             0.10
# LinearRegression                                 0.67             0.10
# Lars                                             0.67             0.10
# DummyRegressor                                   0.13            -0.06
# PoissonRegressor                                44.91           -17.24
# GaussianProcessRegressor                        12.09            -4.71
#
#                                R-Squared_std  RMSE_media  RMSE_std  \
# SVR                                     0.04     3052.27    867.90
# QuantileRegressor                       0.04     3054.57    868.27
# RANSACRegressor                         0.24     2648.27    776.89
# NuSVR                                   0.04     3016.59    864.53
# PassiveAggressiveRegressor              0.33     2598.09    737.36
# ExtraTreesRegressor                     0.49     2392.41    606.17
# HuberRegressor                          0.51     2701.59    697.61
# RandomForestRegressor                   0.53     2368.28    555.36
# XGBRegressor                            1.12     2724.31    638.37
# GradientBoostingRegressor               0.85     2575.93    566.00
# BaggingRegressor                        0.63     2411.72    544.33
# ExtraTreeRegressor                      1.15     2957.02    658.05
# KNeighborsRegressor                     0.40     2541.45    602.02
# LinearSVR                               0.18     3408.35    850.59
# DecisionTreeRegressor                   1.40     2932.58    719.04
# OrthogonalMatchingPursuit               0.43     2430.33    674.43
# LGBMRegressor                           0.41     2388.13    522.36
# HistGradientBoostingRegressor           0.45     2377.25    521.41
# GammaRegressor                          1.55     3215.87   1484.10
# OrthogonalMatchingPursuitCV             0.52     2512.74    641.47
# ElasticNet                              0.20     2485.73    603.02
# TweedieRegressor                        0.12     2538.12    651.80
# RidgeCV                                 0.44     2454.67    557.15
# MLPRegressor                            0.26     3528.82    837.36
# LassoLarsIC                             0.54     2462.36    531.83
# BayesianRidge                           0.49     2468.93    533.06
# AdaBoostRegressor                       0.43     2529.92    622.13
# ElasticNetCV                            0.09     2563.38    656.98
# KernelRidge                             0.53     2455.89    530.02
# LassoCV                                 0.42     2643.33    636.14
# LassoLarsCV                             0.42     2649.23    631.43
# LarsCV                                  0.42     2649.23    631.43
# Ridge                                   0.53     2456.18    528.99
# LassoLars                               0.55     2459.94    527.53
# Lasso                                   0.55     2459.93    527.52
# SGDRegressor                            0.54     2465.85    530.01
# TransformedTargetRegressor              0.55     2460.14    527.36
# LinearRegression                        0.55     2460.14    527.36
# Lars                                    0.55     2460.14    527.36
# DummyRegressor                          0.11     2942.97    766.98
# PoissonRegressor                       36.98     8123.46  10634.40
# GaussianProcessRegressor                9.96     5423.01   2783.36
#
#                                Time Taken_media  Time Taken_std  \
# SVR                                        0.01            0.00
# QuantileRegressor                          0.13            0.03
# RANSACRegressor                            0.05            0.01
# NuSVR                                      0.01            0.00
# PassiveAggressiveRegressor                 0.01            0.00
# ExtraTreesRegressor                        0.05            0.00
# HuberRegressor                             0.02            0.01
# RandomForestRegressor                      0.07            0.01
# XGBRegressor                               0.19            0.05
# GradientBoostingRegressor                  0.04            0.01
# BaggingRegressor                           0.02            0.00
# ExtraTreeRegressor                         0.01            0.00
# KNeighborsRegressor                        0.01            0.00
# LinearSVR                                  0.01            0.00
# DecisionTreeRegressor                      0.01            0.00
# OrthogonalMatchingPursuit                  0.01            0.00
# LGBMRegressor                              0.14            0.02
# HistGradientBoostingRegressor              0.34            0.08
# GammaRegressor                             0.01            0.00
# OrthogonalMatchingPursuitCV                0.01            0.00
# ElasticNet                                 0.01            0.00
# TweedieRegressor                           0.01            0.00
# RidgeCV                                    0.01            0.00
# MLPRegressor                               0.11            0.04
# LassoLarsIC                                0.01            0.00
# BayesianRidge                              0.01            0.00
# AdaBoostRegressor                          0.06            0.01
# ElasticNetCV                               0.03            0.00
# KernelRidge                                0.01            0.01
# LassoCV                                    0.03            0.00
# LassoLarsCV                                0.01            0.00
# LarsCV                                     0.01            0.01
# Ridge                                      0.01            0.00
# LassoLars                                  0.01            0.00
# Lasso                                      0.01            0.00
# SGDRegressor                               0.01            0.00
# TransformedTargetRegressor                 0.01            0.00
# LinearRegression                           0.01            0.00
# Lars                                       0.01            0.00
# DummyRegressor                             0.01            0.00
# PoissonRegressor                           0.01            0.00
# GaussianProcessRegressor                   0.01            0.00
#
#                                mean_absolute_percentage_error_media  \
# SVR                                                            0.49
# QuantileRegressor                                              0.49
# RANSACRegressor                                                0.53
# NuSVR                                                          0.57
# PassiveAggressiveRegressor                                     0.57
# ExtraTreesRegressor                                            0.59
# HuberRegressor                                                 0.64
# RandomForestRegressor                                          0.66
# XGBRegressor                                                   0.68
# GradientBoostingRegressor                                      0.68
# BaggingRegressor                                               0.69
# ExtraTreeRegressor                                             0.71
# KNeighborsRegressor                                            0.73
# LinearSVR                                                      0.76
# DecisionTreeRegressor                                          0.77
# OrthogonalMatchingPursuit                                      0.79
# LGBMRegressor                                                  0.80
# HistGradientBoostingRegressor                                  0.80
# GammaRegressor                                                 0.86
# OrthogonalMatchingPursuitCV                                    0.91
# ElasticNet                                                     0.93
# TweedieRegressor                                               0.96
# RidgeCV                                                        0.98
# MLPRegressor                                                   0.99
# LassoLarsIC                                                    0.99
# BayesianRidge                                                  0.99
# AdaBoostRegressor                                              1.00
# ElasticNetCV                                                   1.01
# KernelRidge                                                    1.01
# LassoCV                                                        1.01
# LassoLarsCV                                                    1.01
# LarsCV                                                         1.01
# Ridge                                                          1.01
# LassoLars                                                      1.02
# Lasso                                                          1.02
# SGDRegressor                                                   1.02
# TransformedTargetRegressor                                     1.02
# LinearRegression                                               1.02
# Lars                                                           1.02
# DummyRegressor                                                 1.23
# PoissonRegressor                                               1.23
# GaussianProcessRegressor                                       2.38
#
#                                mean_absolute_percentage_error_std
# SVR                                                          0.06
# QuantileRegressor                                            0.06
# RANSACRegressor                                              0.23
# NuSVR                                                        0.08
# PassiveAggressiveRegressor                                   0.25
# ExtraTreesRegressor                                          0.26
# HuberRegressor                                               0.29
# RandomForestRegressor                                        0.25
# XGBRegressor                                                 0.39
# GradientBoostingRegressor                                    0.28
# BaggingRegressor                                             0.27
# ExtraTreeRegressor                                           0.41
# KNeighborsRegressor                                          0.26
# LinearSVR                                                    0.01
# DecisionTreeRegressor                                        0.44
# OrthogonalMatchingPursuit                                    0.11
# LGBMRegressor                                                0.15
# HistGradientBoostingRegressor                                0.15
# GammaRegressor                                               0.26
# OrthogonalMatchingPursuitCV                                  0.30
# ElasticNet                                                   0.23
# TweedieRegressor                                             0.20
# RidgeCV                                                      0.28
# MLPRegressor                                                 0.00
# LassoLarsIC                                                  0.30
# BayesianRidge                                                0.30
# AdaBoostRegressor                                            0.31
# ElasticNetCV                                                 0.19
# KernelRidge                                                  0.30
# LassoCV                                                      0.29
# LassoLarsCV                                                  0.29
# LarsCV                                                       0.29
# Ridge                                                        0.30
# LassoLars                                                    0.31
# Lasso                                                        0.31
# SGDRegressor                                                 0.31
# TransformedTargetRegressor                                   0.31
# LinearRegression                                             0.31
# Lars                                                         0.31
# DummyRegressor                                               0.19
# PoissonRegressor                                             0.88
# GaussianProcessRegressor                                     1.88

# %% [markdown]
# # Novo Database

# %%
tabela = '/home/igor/Documentos/stemis/Api_Vitrine/webscraping/dataSetVitrine.xlsx'
df = pd.read_excel(tabela)

df.drop(df.columns[df.columns.str.contains('unnamed', case=False)], axis=1, inplace=True)
df = df.drop(['Bairro'], axis=1)

money_cols = ['Preço']  # Lista das colunas de dinheiro

for col in money_cols:
    df[col] = df[col].astype(str).apply(lambda x: x.replace('.', ''))
    df[col] = df[col].replace({'R\$ ': '', ',': '.'}, regex=True).astype('float64')

int_cols = ['Quartos', 'Banheiros', 'Vagas']  # Lista das colunas de números inteiros

for col in int_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce').astype('Int64')

df = df.drop_duplicates()

df = df.reset_index(drop=True)

df.to_csv('dataSetVitrine.csv', index=False)

property_types = df['Tipo'].unique()
property_dfs = {}

for property_type in property_types:
    property_dfs[property_type] = df[df['Tipo'] == property_type]

# %% [markdown]
# # Apartamento Novo

# %%
results_dict = train(property_dfs,"Apartamento")

results_dict_format = {}

#imprime
for model in results_dict:
    results_dict_format[model]={}
    for metric in results_dict[model]:
        mean = np.mean(results_dict[model][metric]["mean"])
        std = np.std(results_dict[model][metric]["mean"])
        results_dict_format[model][metric + "_media"] = mean
        results_dict_format[model][metric + "_std"] = std

df = pd.DataFrame(results_dict_format)
df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
# Out:
#   0%|          | 0/42 [00:00<?, ?it/s]
# 100%|██████████| 42/42 [00:00<00:00, 51.14it/s]
# 100%|██████████| 42/42 [00:00<00:00, 56.79it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.83it/s]
# 100%|██████████| 42/42 [00:00<00:00, 47.44it/s]
# 100%|██████████| 42/42 [00:01<00:00, 40.80it/s]
#  14%|█▍        | 6/42 [00:00<00:00, 50.52it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 results_dict = train(property_dfs,"Apartamento")
#       3 results_dict_format = {}
#       5 #imprime
#
# Cell In[66], line 21, in train(property_dfs, tipo)
#      18 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)
#      20 reg = LazyRegressor(verbose=0, ignore_warnings=True, custom_metric= mean_absolute_percentage_error)
# ---> 21 models, _ = reg.fit(X_train, X_test, y_train, y_test)
#      23 for model_name, methods in models.iterrows():
#      25     if model_name not in dict_result:
#
# File ~/anaconda3/lib/python3.10/site-packages/lazypredict/Supervised.py:603, in LazyRegressor.fit(self, X_train, X_test, y_train, y_test)
#     598 else:
#     599     pipe = Pipeline(
#     600         steps=[("preprocessor", preprocessor), ("regressor", model())]
#     601     )
# --> 603 pipe.fit(X_train, y_train)
#     604 self.models[name] = pipe
#     605 y_pred = pipe.predict(X_test)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/pipeline.py:420, in Pipeline.fit(self, X, y, **fit_params)
#     418     if self._final_estimator != "passthrough":
#     419         fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 420         self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     422 return self
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1663, in LinearModelCV.fit(self, X, y, sample_weight)
#    1643 # We do a double for loop folded in one, in order to be able to
#    1644 # iterate in parallel on l1_ratio and folds
#    1645 jobs = (
#    1646     delayed(_path_residuals)(
#    1647         X,
#    (...)
#    1661     for train, test in folds
#    1662 )
# -> 1663 mse_paths = Parallel(
#    1664     n_jobs=self.n_jobs,
#    1665     verbose=self.verbose,
#    1666     prefer="threads",
#    1667 )(jobs)
#    1668 mse_paths = np.reshape(mse_paths, (n_l1_ratio, len(folds), -1))
#    1669 # The mean is computed over folds.
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.10/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:1389, in _path_residuals(X, y, sample_weight, train, test, fit_intercept, path, path_params, alphas, l1_ratio, X_order, dtype)
#    1386 # Do the ordering and type casting here, as if it is done in the path,
#    1387 # X is copied and a reference is kept here
#    1388 X_train = check_array(X_train, accept_sparse="csc", dtype=dtype, order=X_order)
# -> 1389 alphas, coefs, _ = path(X_train, y_train, **path_params)
#    1390 del X_train, y_train
#    1392 if y.ndim == 1:
#    1393     # Doing this so that it becomes coherent with multioutput.
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/linear_model/_coordinate_descent.py:614, in enet_path(X, y, l1_ratio, eps, n_alphas, alphas, precompute, Xy, copy_X, coef_init, verbose, return_n_iter, positive, check_input, **params)
#     612     if check_input:
#     613         precompute = check_array(precompute, dtype=X.dtype.type, order="C")
# --> 614     model = cd_fast.enet_coordinate_descent_gram(
#     615         coef_,
#     616         l1_reg,
#     617         l2_reg,
#     618         precompute,
#     619         Xy,
#     620         y,
#     621         max_iter,
#     622         tol,
#     623         rng,
#     624         random,
#     625         positive,
#     626     )
#     627 elif precompute is False:
#     628     model = cd_fast.enet_coordinate_descent(
#     629         coef_, l1_reg, l2_reg, X, y, max_iter, tol, rng, random, positive
#     630     )
#
# File sklearn/linear_model/_cd_fast.pyx:632, in sklearn.linear_model._cd_fast.enet_coordinate_descent_gram()
#
# File ~/anaconda3/lib/python3.10/site-packages/numpy/core/multiarray.py:741, in dot(a, b, out)
#     671     """
#     672     result_type(*arrays_and_dtypes)
#     673
#    (...)
#     736
#     737     """
#     738     return arrays_and_dtypes
# --> 741 @array_function_from_c_func_and_dispatcher(_multiarray_umath.dot)
#     742 def dot(a, b, out=None):
#     743     """
#     744     dot(a, b, out=None)
#     745
#    (...)
#     829
#     830     """
#     831     return (a, b, out)
#
# KeyboardInterrupt:

# %% [markdown]
# # Casa Novo

# %%
results_dict = train(property_dfs,"Casa")

results_dict_format = {}

#imprime
for model in results_dict:
    results_dict_format[model]={}
    for metric in results_dict[model]:
        mean = np.mean(results_dict[model][metric]["mean"])
        std = np.std(results_dict[model][metric]["mean"])
        results_dict_format[model][metric + "_media"] = mean
        results_dict_format[model][metric + "_std"] = std

df = pd.DataFrame(results_dict_format)
df.transpose().sort_values(by=["mean_absolute_percentage_error_media"])
# Out:
# 100%|██████████| 42/42 [00:01<00:00, 23.87it/s]
# 100%|██████████| 42/42 [00:01<00:00, 27.96it/s]
# 100%|██████████| 42/42 [00:01<00:00, 22.85it/s]
# 100%|██████████| 42/42 [00:01<00:00, 22.92it/s]
# 100%|██████████| 42/42 [00:01<00:00, 28.05it/s]
# 100%|██████████| 42/42 [00:01<00:00, 29.25it/s]
# 100%|██████████| 42/42 [00:01<00:00, 35.61it/s]
# 100%|██████████| 42/42 [00:01<00:00, 26.01it/s]
# 100%|██████████| 42/42 [00:01<00:00, 22.64it/s]
# 100%|██████████| 42/42 [00:01<00:00, 24.15it/s]
# 100%|██████████| 42/42 [00:02<00:00, 18.94it/s]
# 100%|██████████| 42/42 [00:01<00:00, 23.79it/s]
# 100%|██████████| 42/42 [00:01<00:00, 29.55it/s]
# 100%|██████████| 42/42 [00:01<00:00, 25.66it/s]
# 100%|██████████| 42/42 [00:01<00:00, 28.19it/s]
# 100%|██████████| 42/42 [00:01<00:00, 29.96it/s]
# 100%|██████████| 42/42 [00:01<00:00, 27.53it/s]
# 100%|██████████| 42/42 [00:01<00:00, 27.95it/s]
# 100%|██████████| 42/42 [00:01<00:00, 24.57it/s]
# 100%|██████████| 42/42 [00:01<00:00, 30.91it/s]
# 100%|██████████| 42/42 [00:01<00:00, 32.20it/s]
# 100%|██████████| 42/42 [00:01<00:00, 31.76it/s]
# 100%|██████████| 42/42 [00:01<00:00, 34.23it/s]
# 100%|██████████| 42/42 [00:01<00:00, 29.89it/s]
# 100%|██████████| 42/42 [00:01<00:00, 31.68it/s]
# 100%|██████████| 42/42 [00:00<00:00, 43.34it/s]
# 100%|██████████| 42/42 [00:01<00:00, 34.87it/s]
# 100%|██████████| 42/42 [00:01<00:00, 35.36it/s]
# 100%|██████████| 42/42 [00:01<00:00, 37.89it/s]
# 100%|██████████| 42/42 [00:01<00:00, 26.64it/s]
# 100%|██████████| 42/42 [00:01<00:00, 31.64it/s]
# 100%|██████████| 42/42 [00:01<00:00, 37.47it/s]
# 100%|██████████| 42/42 [00:01<00:00, 36.08it/s]
#                                Adjusted R-Squared_media  \
# AdaBoostRegressor                                  1.00
# ExtraTreesRegressor                                1.00
# KNeighborsRegressor                                1.00
# BaggingRegressor                                   1.00
# ExtraTreeRegressor                                 1.00
# RandomForestRegressor                              1.00
# DecisionTreeRegressor                              1.00
# LinearRegression                                   1.00
# TransformedTargetRegressor                         1.00
# BayesianRidge                                      1.00
# OrthogonalMatchingPursuitCV                        1.00
# OrthogonalMatchingPursuit                          1.00
# LarsCV                                             1.00
# Lars                                               1.00
# LassoLarsCV                                        1.00
# GaussianProcessRegressor                           1.00
# HuberRegressor                                     1.00
# XGBRegressor                                       1.00
# PassiveAggressiveRegressor                         1.00
# HistGradientBoostingRegressor                      1.00
# LGBMRegressor                                      1.00
# GradientBoostingRegressor                          1.00
# SGDRegressor                                       1.00
# Lasso                                              1.00
# LassoLars                                          1.00
# KernelRidge                                        1.00
# RidgeCV                                            1.00
# PoissonRegressor                                   1.00
# RANSACRegressor                                    0.97
# LassoCV                                            1.00
# Ridge                                              1.00
# LassoLarsIC                                        0.97
# LinearSVR                                         -1.89
# MLPRegressor                                      -2.28
# GammaRegressor                                     0.65
# ElasticNet                                         0.88
# TweedieRegressor                                   0.75
# ElasticNetCV                                       0.45
# NuSVR                                             -0.17
# DummyRegressor                                    -0.07
# SVR                                               -0.53
# QuantileRegressor                                 -0.59
#
#                                Adjusted R-Squared_std  R-Squared_media  \
# AdaBoostRegressor                                0.00             1.00
# ExtraTreesRegressor                              0.00             1.00
# KNeighborsRegressor                              0.00             1.00
# BaggingRegressor                                 0.00             1.00
# ExtraTreeRegressor                               0.00             1.00
# RandomForestRegressor                            0.00             1.00
# DecisionTreeRegressor                            0.00             1.00
# LinearRegression                                 0.00             1.00
# TransformedTargetRegressor                       0.00             1.00
# BayesianRidge                                    0.00             1.00
# OrthogonalMatchingPursuitCV                      0.00             1.00
# OrthogonalMatchingPursuit                        0.00             1.00
# LarsCV                                           0.00             1.00
# Lars                                             0.00             1.00
# LassoLarsCV                                      0.00             1.00
# GaussianProcessRegressor                         0.00             1.00
# HuberRegressor                                   0.00             1.00
# XGBRegressor                                     0.00             1.00
# PassiveAggressiveRegressor                       0.00             1.00
# HistGradientBoostingRegressor                    0.00             1.00
# LGBMRegressor                                    0.00             1.00
# GradientBoostingRegressor                        0.00             1.00
# SGDRegressor                                     0.00             1.00
# Lasso                                            0.00             1.00
# LassoLars                                        0.00             1.00
# KernelRidge                                      0.00             1.00
# RidgeCV                                          0.00             1.00
# PoissonRegressor                                 0.00             1.00
# RANSACRegressor                                  0.10             0.98
# LassoCV                                          0.00             1.00
# Ridge                                            0.00             1.00
# LassoLarsIC                                      0.18             0.97
# LinearSVR                                        0.33            -1.74
# MLPRegressor                                     0.37            -2.10
# GammaRegressor                                   0.07             0.67
# ElasticNet                                       0.01             0.89
# TweedieRegressor                                 0.01             0.77
# ElasticNetCV                                     0.01             0.48
# NuSVR                                            0.07            -0.11
# DummyRegressor                                   0.02            -0.01
# SVR                                              0.08            -0.45
# QuantileRegressor                                0.08            -0.50
#
#                                R-Squared_std  RMSE_media  RMSE_std  \
# AdaBoostRegressor                       0.00        0.00      0.00
# ExtraTreesRegressor                     0.00        0.00      0.00
# KNeighborsRegressor                     0.00        0.00      0.00
# BaggingRegressor                        0.00        0.00      0.00
# ExtraTreeRegressor                      0.00        0.00      0.00
# RandomForestRegressor                   0.00        0.00      0.00
# DecisionTreeRegressor                   0.00        0.00      0.00
# LinearRegression                        0.00        0.00      0.00
# TransformedTargetRegressor              0.00        0.00      0.00
# BayesianRidge                           0.00        0.00      0.00
# OrthogonalMatchingPursuitCV             0.00        0.00      0.00
# OrthogonalMatchingPursuit               0.00        0.00      0.00
# LarsCV                                  0.00        0.00      0.00
# Lars                                    0.00        0.00      0.00
# LassoLarsCV                             0.00        0.00      0.00
# GaussianProcessRegressor                0.00        0.00      0.00
# HuberRegressor                          0.00        0.00      0.00
# XGBRegressor                            0.00        0.00      0.00
# PassiveAggressiveRegressor              0.00        0.06      0.02
# HistGradientBoostingRegressor           0.00        0.08      0.00
# LGBMRegressor                           0.00        0.08      0.00
# GradientBoostingRegressor               0.00        0.08      0.00
# SGDRegressor                            0.00        0.37      0.02
# Lasso                                   0.00        1.00      0.03
# LassoLars                               0.00        1.00      0.03
# KernelRidge                             0.00       21.13      1.08
# RidgeCV                                 0.00        1.32      0.05
# PoissonRegressor                        0.00        2.14      0.08
# RANSACRegressor                         0.10      114.94    452.51
# LassoCV                                 0.00        3.01      0.07
# Ridge                                   0.00       13.15      0.49
# LassoLarsIC                             0.17       92.56    523.58
# LinearSVR                               0.31     4936.66    126.49
# MLPRegressor                            0.35     5256.09    132.19
# GammaRegressor                          0.06     1720.60    109.59
# ElasticNet                              0.01      993.87     23.99
# TweedieRegressor                        0.01     1444.98     33.90
# ElasticNetCV                            0.01     2164.35     46.55
# NuSVR                                   0.07     3143.64      0.34
# DummyRegressor                          0.02     3009.49     71.47
# SVR                                     0.07     3600.89    190.17
# QuantileRegressor                       0.07     3668.21    191.36
#
#                                Time Taken_media  Time Taken_std  \
# AdaBoostRegressor                          0.02            0.01
# ExtraTreesRegressor                        0.04            0.00
# KNeighborsRegressor                        0.01            0.00
# BaggingRegressor                           0.03            0.01
# ExtraTreeRegressor                         0.01            0.00
# RandomForestRegressor                      0.05            0.01
# DecisionTreeRegressor                      0.01            0.00
# LinearRegression                           0.01            0.00
# TransformedTargetRegressor                 0.01            0.00
# BayesianRidge                              0.01            0.00
# OrthogonalMatchingPursuitCV                0.01            0.00
# OrthogonalMatchingPursuit                  0.01            0.01
# LarsCV                                     0.01            0.00
# Lars                                       0.01            0.00
# LassoLarsCV                                0.01            0.00
# GaussianProcessRegressor                   0.01            0.00
# HuberRegressor                             0.03            0.01
# XGBRegressor                               0.05            0.02
# PassiveAggressiveRegressor                 0.01            0.00
# HistGradientBoostingRegressor              0.17            0.07
# LGBMRegressor                              0.07            0.03
# GradientBoostingRegressor                  0.03            0.01
# SGDRegressor                               0.01            0.00
# Lasso                                      0.01            0.00
# LassoLars                                  0.01            0.00
# KernelRidge                                0.01            0.00
# RidgeCV                                    0.01            0.00
# PoissonRegressor                           0.01            0.00
# RANSACRegressor                            0.03            0.01
# LassoCV                                    0.03            0.00
# Ridge                                      0.01            0.00
# LassoLarsIC                                0.01            0.00
# LinearSVR                                  0.01            0.00
# MLPRegressor                               0.16            0.07
# GammaRegressor                             0.01            0.00
# ElasticNet                                 0.01            0.00
# TweedieRegressor                           0.01            0.00
# ElasticNetCV                               0.03            0.00
# NuSVR                                      0.02            0.01
# DummyRegressor                             0.01            0.00
# SVR                                        0.01            0.00
# QuantileRegressor                          0.47            0.12
#
#                                mean_absolute_percentage_error_media  \
# AdaBoostRegressor                                              0.00
# ExtraTreesRegressor                                            0.00
# KNeighborsRegressor                                            0.00
# BaggingRegressor                                               0.00
# ExtraTreeRegressor                                             0.00
# RandomForestRegressor                                          0.00
# DecisionTreeRegressor                                          0.00
# LinearRegression                                               0.00
# TransformedTargetRegressor                                     0.00
# BayesianRidge                                                  0.00
# OrthogonalMatchingPursuitCV                                    0.00
# OrthogonalMatchingPursuit                                      0.00
# LarsCV                                                         0.00
# Lars                                                           0.00
# LassoLarsCV                                                    0.00
# GaussianProcessRegressor                                       0.00
# HuberRegressor                                                 0.00
# XGBRegressor                                                   0.00
# PassiveAggressiveRegressor                                     0.00
# HistGradientBoostingRegressor                                  0.00
# LGBMRegressor                                                  0.00
# GradientBoostingRegressor                                      0.00
# SGDRegressor                                                   0.00
# Lasso                                                          0.00
# LassoLars                                                      0.00
# KernelRidge                                                    0.00
# RidgeCV                                                        0.00
# PoissonRegressor                                               0.01
# RANSACRegressor                                                0.01
# LassoCV                                                        0.01
# Ridge                                                          0.04
# LassoLarsIC                                                    0.38
# LinearSVR                                                      0.62
# MLPRegressor                                                   0.96
# GammaRegressor                                                 2.64
# ElasticNet                                                     3.60
# TweedieRegressor                                               5.38
# ElasticNetCV                                                   8.24
# NuSVR                                                          8.67
# DummyRegressor                                                11.52
# SVR                                                           16.62
# QuantileRegressor                                             16.93
#
#                                mean_absolute_percentage_error_std
# AdaBoostRegressor                                            0.00
# ExtraTreesRegressor                                          0.00
# KNeighborsRegressor                                          0.00
# BaggingRegressor                                             0.00
# ExtraTreeRegressor                                           0.00
# RandomForestRegressor                                        0.00
# DecisionTreeRegressor                                        0.00
# LinearRegression                                             0.00
# TransformedTargetRegressor                                   0.00
# BayesianRidge                                                0.00
# OrthogonalMatchingPursuitCV                                  0.00
# OrthogonalMatchingPursuit                                    0.00
# LarsCV                                                       0.00
# Lars                                                         0.00
# LassoLarsCV                                                  0.00
# GaussianProcessRegressor                                     0.00
# HuberRegressor                                               0.00
# XGBRegressor                                                 0.00
# PassiveAggressiveRegressor                                   0.00
# HistGradientBoostingRegressor                                0.00
# LGBMRegressor                                                0.00
# GradientBoostingRegressor                                    0.00
# SGDRegressor                                                 0.00
# Lasso                                                        0.00
# LassoLars                                                    0.00
# KernelRidge                                                  0.00
# RidgeCV                                                      0.00
# PoissonRegressor                                             0.00
# RANSACRegressor                                              0.04
# LassoCV                                                      0.00
# Ridge                                                        0.01
# LassoLarsIC                                                  2.13
# LinearSVR                                                    0.03
# MLPRegressor                                                 0.00
# GammaRegressor                                               0.35
# ElasticNet                                                   0.44
# TweedieRegressor                                             0.65
# ElasticNetCV                                                 0.97
# NuSVR                                                        0.84
# DummyRegressor                                               1.36
# SVR                                                          1.71
# QuantileRegressor                                            1.73
